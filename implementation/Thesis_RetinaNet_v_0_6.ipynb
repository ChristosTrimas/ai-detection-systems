# %%
# !pip uninstall keras -y
# !pip uninstall keras-nightly -y
# !pip uninstall keras-Preprocessing -y
# !pip uninstall keras-vis -y
# !pip uninstall tensorflow -y

# !pip install tensorflow==2.3.0
# !pip install keras==2.4
# Out:
# Uninstalling Keras-2.4.3:
#   Successfully uninstalled Keras-2.4.3
# Uninstalling keras-nightly-2.5.0.dev2021032900:
#   Successfully uninstalled keras-nightly-2.5.0.dev2021032900
# Uninstalling Keras-Preprocessing-1.1.2:
#   Successfully uninstalled Keras-Preprocessing-1.1.2
# Uninstalling keras-vis-0.4.1:
#   Successfully uninstalled keras-vis-0.4.1
# Uninstalling tensorflow-2.5.0:
#   Successfully uninstalled tensorflow-2.5.0
# Collecting tensorflow==2.3.0
#   Downloading https://files.pythonhosted.org/packages/16/89/f2d29c2eafc2eeafb17d5634340e06366af904d332341200a49d954bce85/tensorflow-2.3.0-cp37-cp37m-manylinux2010_x86_64.whl (320.4MB)
#      |████████████████████████████████| 320.4MB 21kB/s
# Collecting keras-preprocessing<1.2,>=1.1.1
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 8.8MB/s
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.36.2)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.34.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.12.4)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading https://files.pythonhosted.org/packages/e9/ed/5853ec0ae380cba4588eab1524e18ece1583b65f7ae0e97321f5ff9dfd60/tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459kB)
#      |████████████████████████████████| 460kB 57.7MB/s
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading https://files.pythonhosted.org/packages/d6/c6/58e517e8b1fb192725cfa23c01c2e60e4e6699314ee9684a1c5f5c9b27e1/numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.1MB 316kB/s
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 39.2MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Collecting gast==0.3.3
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.5.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.4.1)
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, keras-preprocessing, tensorflow-estimator, h5py, gast, tensorflow
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
# Successfully installed gast-0.3.3 h5py-2.10.0 keras-preprocessing-1.1.2 numpy-1.18.5 tensorflow-2.3.0 tensorflow-estimator-2.3.0
# Collecting keras==2.4
#   Downloading https://files.pythonhosted.org/packages/b6/19/9d8f1c86c09d05369da39b03d011cd689edef86c0e6b2777dbcedc49dfc6/Keras-2.4.0-py2.py3-none-any.whl (170kB)
#      |████████████████████████████████| 174kB 7.4MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.4) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.4) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.4) (2.10.0)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.4) (2.3.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.4) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.4) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (3.12.4)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.34.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.3.3)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (2.5.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.36.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow>=2.2.0->keras==2.4) (57.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (1.31.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras==2.4) (3.4.1)
# Installing collected packages: keras
# Successfully installed keras-2.4.0

# %%
# !nvidia-smi
# Out:
# Mon Jun 28 13:47:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #Keras RetinaNet setup
# importing the git repository

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6205, done.
# remote: Total 6205 (delta 0), reused 0 (delta 0), pack-reused 6205
# Receiving objects: 100% (6205/6205), 13.47 MiB | 32.83 MiB/s, done.
# Resolving deltas: 100% (4201/4201), done.

# %% [markdown]
# upgrade keras to latest update

# %%
# %cd keras-retinanet/
# !pip install .
# Out:
# /content/keras-retinanet
# Processing /content/keras-retinanet
# Collecting keras-resnet==0.2.0
#   Downloading https://files.pythonhosted.org/packages/76/d4/a35cbd07381139dda4db42c81b88c59254faac026109022727b45b31bcad/keras-resnet-0.2.0.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (1.18.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (0.29.23)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (7.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (4.1.2.30)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.7/dist-packages (from keras-retinanet==1.0.0) (3.38.0)
# Requirement already satisfied: keras>=2.2.4 in /usr/local/lib/python3.7/dist-packages (from keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.4.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2->keras-retinanet==1.0.0) (2.5.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.13)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.3.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.1.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.36.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.34.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.12.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.31.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (57.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (4.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (3.1.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->keras>=2.2.4->keras-resnet==0.2.0->keras-retinanet==1.0.0) (0.4.8)
# Building wheels for collected packages: keras-retinanet, keras-resnet
#   Building wheel for keras-retinanet (setup.py) ... done
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp37-cp37m-linux_x86_64.whl size=169098 sha256=b933058fd52a1676bf4fdf6b5b7e42c335cab70347f2559d15858fda5b9803b8
#   Stored in directory: /root/.cache/pip/wheels/b2/9f/57/cb0305f6f5a41fc3c11ad67b8cedfbe9127775b563337827ba
#   Building wheel for keras-resnet (setup.py) ... done
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20487 sha256=18ea945b6fbf22f9a0d61c668b014efea9eb93afbda53880d36f6ed9fcad3a78
#   Stored in directory: /root/.cache/pip/wheels/5f/09/a5/497a30fd9ad9964e98a1254d1e164bcd1b8a5eda36197ecb3c
# Successfully built keras-retinanet keras-resnet
# Installing collected packages: keras-resnet, keras-retinanet
# Successfully installed keras-resnet-0.2.0 keras-retinanet-1.0.0

# %% [markdown]
# setup the model

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/keras-retinanet/keras_retinanet/utils/compute_overlap.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'keras_retinanet.utils.compute_overlap' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/keras_retinanet
# creating build/temp.linux-x86_64-3.7/keras_retinanet/utils
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-OGiuun/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-OGiuun/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -c keras_retinanet/utils/compute_overlap.c -o build/temp.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.o
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from keras_retinanet/utils/compute_overlap.c:612:
# /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/keras_retinanet
# creating build/lib.linux-x86_64-3.7/keras_retinanet/utils
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-OGiuun/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.o -o build/lib.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.cpython-37m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.7/keras_retinanet/utils/compute_overlap.cpython-37m-x86_64-linux-gnu.so -> keras_retinanet/utils

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (3.0.4)

# %% [markdown]
# Usefull libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters
from sklearn.model_selection import train_test_split
import urllib
import os
import csv
import cv2
import time
from PIL import Image

from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

print("Setup ready")
# Out:
# Setup ready

# %% [markdown]
# Upload dataset into a pands dataframe

# %%
# !gdown --id 1mOK2qtcY9oNiAhWbOgvj4v8e9FuqcGIB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mOK2qtcY9oNiAhWbOgvj4v8e9FuqcGIB
# To: /content/keras-retinanet/imgs.zip
# 935MB [00:10, 89.7MB/s]

# %%
# !unzip imgs.zip
# Out:
# Archive:  imgs.zip
#    creating: imgs/test/
#   inflating: imgs/test/bookstore_video1_10020.jpg
#   inflating: imgs/test/bookstore_video1_10050.jpg
#   inflating: imgs/test/bookstore_video1_10080.jpg
#   inflating: imgs/test/bookstore_video1_10110.jpg
#   inflating: imgs/test/bookstore_video1_10140.jpg
#   inflating: imgs/test/bookstore_video1_10170.jpg
#   inflating: imgs/test/bookstore_video1_10200.jpg
#   inflating: imgs/test/bookstore_video1_10230.jpg
#   inflating: imgs/test/bookstore_video1_10260.jpg
#   inflating: imgs/test/bookstore_video1_10290.jpg
#   inflating: imgs/test/bookstore_video1_10320.jpg
#   inflating: imgs/test/bookstore_video1_10350.jpg
#   inflating: imgs/test/bookstore_video1_10380.jpg
#   inflating: imgs/test/bookstore_video1_10410.jpg
#   inflating: imgs/test/bookstore_video1_10440.jpg
#   inflating: imgs/test/bookstore_video1_10470.jpg
#   inflating: imgs/test/bookstore_video1_10500.jpg
#   inflating: imgs/test/bookstore_video1_10530.jpg
#   inflating: imgs/test/bookstore_video1_10560.jpg
#   inflating: imgs/test/bookstore_video1_10590.jpg
#   inflating: imgs/test/bookstore_video1_10620.jpg
#   inflating: imgs/test/bookstore_video1_10650.jpg
#   inflating: imgs/test/bookstore_video1_10680.jpg
#   inflating: imgs/test/bookstore_video1_10710.jpg
#   inflating: imgs/test/bookstore_video1_10740.jpg
#   inflating: imgs/test/bookstore_video1_10770.jpg
#   inflating: imgs/test/bookstore_video1_10800.jpg
#   inflating: imgs/test/bookstore_video1_10830.jpg
#   inflating: imgs/test/bookstore_video1_10860.jpg
#   inflating: imgs/test/bookstore_video1_10890.jpg
#   inflating: imgs/test/bookstore_video1_10920.jpg
#   inflating: imgs/test/bookstore_video1_10950.jpg
#   inflating: imgs/test/bookstore_video1_10980.jpg
#   inflating: imgs/test/bookstore_video1_11010.jpg
#   inflating: imgs/test/bookstore_video1_11040.jpg
#   inflating: imgs/test/bookstore_video1_11070.jpg
#   inflating: imgs/test/bookstore_video1_11100.jpg
#   inflating: imgs/test/bookstore_video1_11130.jpg
#   inflating: imgs/test/bookstore_video1_11160.jpg
#   inflating: imgs/test/bookstore_video1_11190.jpg
#   inflating: imgs/test/bookstore_video1_11220.jpg
#   inflating: imgs/test/bookstore_video1_11250.jpg
#   inflating: imgs/test/bookstore_video1_11280.jpg
#   inflating: imgs/test/bookstore_video1_11310.jpg
#   inflating: imgs/test/bookstore_video1_11340.jpg
#   inflating: imgs/test/bookstore_video1_11370.jpg
#   inflating: imgs/test/bookstore_video1_11400.jpg
#   inflating: imgs/test/bookstore_video1_11430.jpg
#   inflating: imgs/test/bookstore_video1_11460.jpg
#   inflating: imgs/test/bookstore_video1_11490.jpg
#   inflating: imgs/test/bookstore_video1_11520.jpg
#   inflating: imgs/test/bookstore_video1_11550.jpg
#   inflating: imgs/test/bookstore_video1_11580.jpg
#   inflating: imgs/test/bookstore_video1_11610.jpg
#   inflating: imgs/test/bookstore_video1_11640.jpg
#   inflating: imgs/test/bookstore_video1_11670.jpg
#   inflating: imgs/test/bookstore_video1_11700.jpg
#   inflating: imgs/test/bookstore_video1_11730.jpg
#   inflating: imgs/test/bookstore_video1_11760.jpg
#   inflating: imgs/test/bookstore_video1_11790.jpg
#   inflating: imgs/test/bookstore_video1_11820.jpg
#   inflating: imgs/test/bookstore_video1_11850.jpg
#   inflating: imgs/test/bookstore_video1_11880.jpg
#   inflating: imgs/test/bookstore_video1_11910.jpg
#   inflating: imgs/test/bookstore_video1_11940.jpg
#   inflating: imgs/test/bookstore_video1_11970.jpg
#   inflating: imgs/test/bookstore_video1_12000.jpg
#   inflating: imgs/test/bookstore_video1_12030.jpg
#   inflating: imgs/test/bookstore_video1_12060.jpg
#   inflating: imgs/test/bookstore_video1_12090.jpg
#   inflating: imgs/test/bookstore_video1_12120.jpg
#   inflating: imgs/test/bookstore_video1_12150.jpg
#   inflating: imgs/test/bookstore_video1_12180.jpg
#   inflating: imgs/test/bookstore_video1_12210.jpg
#   inflating: imgs/test/bookstore_video1_12240.jpg
#   inflating: imgs/test/bookstore_video1_12270.jpg
#   inflating: imgs/test/bookstore_video1_12300.jpg
#   inflating: imgs/test/bookstore_video1_12330.jpg
#   inflating: imgs/test/bookstore_video1_12360.jpg
#   inflating: imgs/test/bookstore_video1_12390.jpg
#   inflating: imgs/test/bookstore_video1_12420.jpg
#   inflating: imgs/test/bookstore_video1_12450.jpg
#   inflating: imgs/test/bookstore_video1_12480.jpg
#   inflating: imgs/test/bookstore_video1_12510.jpg
#   inflating: imgs/test/bookstore_video1_12540.jpg
#   inflating: imgs/test/bookstore_video1_12570.jpg
#   inflating: imgs/test/bookstore_video1_12600.jpg
#   inflating: imgs/test/bookstore_video1_12630.jpg
#   inflating: imgs/test/bookstore_video1_12660.jpg
#   inflating: imgs/test/bookstore_video1_12690.jpg
#   inflating: imgs/test/bookstore_video1_12720.jpg
#   inflating: imgs/test/bookstore_video1_12750.jpg
#   inflating: imgs/test/bookstore_video1_12780.jpg
#   inflating: imgs/test/bookstore_video1_12810.jpg
#   inflating: imgs/test/bookstore_video1_12840.jpg
#   inflating: imgs/test/bookstore_video1_12870.jpg
#   inflating: imgs/test/bookstore_video1_12900.jpg
#   inflating: imgs/test/bookstore_video1_12930.jpg
#   inflating: imgs/test/bookstore_video1_12960.jpg
#   inflating: imgs/test/bookstore_video1_12990.jpg
#   inflating: imgs/test/bookstore_video1_13020.jpg
#   inflating: imgs/test/bookstore_video1_13050.jpg
#   inflating: imgs/test/bookstore_video1_13080.jpg
#   inflating: imgs/test/bookstore_video1_13110.jpg
#   inflating: imgs/test/bookstore_video1_13140.jpg
#   inflating: imgs/test/bookstore_video1_13170.jpg
#   inflating: imgs/test/bookstore_video1_13200.jpg
#   inflating: imgs/test/bookstore_video1_13230.jpg
#   inflating: imgs/test/bookstore_video1_13260.jpg
#   inflating: imgs/test/bookstore_video1_13290.jpg
#   inflating: imgs/test/bookstore_video1_13320.jpg
#   inflating: imgs/test/bookstore_video1_13350.jpg
#   inflating: imgs/test/bookstore_video1_13380.jpg
#   inflating: imgs/test/bookstore_video1_13410.jpg
#   inflating: imgs/test/bookstore_video1_13440.jpg
#   inflating: imgs/test/bookstore_video1_13470.jpg
#   inflating: imgs/test/bookstore_video1_13500.jpg
#   inflating: imgs/test/bookstore_video1_13530.jpg
#   inflating: imgs/test/bookstore_video1_13560.jpg
#   inflating: imgs/test/bookstore_video1_13590.jpg
#   inflating: imgs/test/bookstore_video1_13620.jpg
#   inflating: imgs/test/bookstore_video1_13650.jpg
#   inflating: imgs/test/bookstore_video1_13680.jpg
#   inflating: imgs/test/bookstore_video1_13710.jpg
#   inflating: imgs/test/bookstore_video1_13740.jpg
#   inflating: imgs/test/bookstore_video1_13770.jpg
#   inflating: imgs/test/bookstore_video1_13800.jpg
#   inflating: imgs/test/bookstore_video1_13830.jpg
#   inflating: imgs/test/bookstore_video1_13860.jpg
#   inflating: imgs/test/bookstore_video1_13890.jpg
#   inflating: imgs/test/bookstore_video1_13920.jpg
#   inflating: imgs/test/bookstore_video1_13950.jpg
#   inflating: imgs/test/bookstore_video1_13980.jpg
#   inflating: imgs/test/bookstore_video1_14010.jpg
#   inflating: imgs/test/bookstore_video1_14040.jpg
#   inflating: imgs/test/bookstore_video1_14070.jpg
#   inflating: imgs/test/bookstore_video1_14100.jpg
#   inflating: imgs/test/bookstore_video1_14130.jpg
#   inflating: imgs/test/bookstore_video1_14160.jpg
#   inflating: imgs/test/bookstore_video1_14190.jpg
#   inflating: imgs/test/bookstore_video1_14220.jpg
#   inflating: imgs/test/bookstore_video1_14250.jpg
#   inflating: imgs/val/quad_video2_210.jpg
#   inflating: imgs/val/quad_video2_240.jpg
#   inflating: imgs/val/quad_video2_270.jpg
#   inflating: imgs/val/quad_video2_60.jpg
#   inflating: imgs/val/quad_video2_90.jpg

# %%
# %ls
os.makedirs("snapshots", exist_ok=True)
# %cd snapshots
# !gdown --id 1c9AcfRrfprAEH5G6lMuyj3rh6Ss539nT
# %cd ..
# Out:
# build/           keras_retinanet/  test_annotations.csv
# config.ini       LICENSE           test_annotations_sorted.csv
# CONTRIBUTORS.md  README.md         tests/
# examples/        requirements.txt  test_sorted.csv
# images/          setup.cfg         train_annotations.csv
# imgs/            setup.py
# imgs.zip         snapshots/

# %%
# %cd snapshots
# !gdown --id 1iyi-MFDKAbHu5e2CTy--jQih0LbR40C5
# !gdown --id 1Dp9_eAGlPcpAY38je0rbZfKFoCIZzV8Q
# %cd ..
# Out:
# /content/keras-retinanet/snapshots
# Downloading...
# From: https://drive.google.com/uc?id=1Dp9_eAGlPcpAY38je0rbZfKFoCIZzV8Q
# To: /content/keras-retinanet/snapshots/resnet50_csv_85.h5
# 438MB [00:03, 132MB/s]
# /content/keras-retinanet

# %%
df = pd.read_csv('train_annotations.csv')
df.head()
# Out:
#    imgs/train/bookstore_video0_40.jpg  763   899  806   940  Person
# 0  imgs/train/bookstore_video0_40.jpg  848   174  891   219  Person
# 1  imgs/train/bookstore_video0_40.jpg  399   999  419  1031  Person
# 2  imgs/train/bookstore_video0_40.jpg  417  1033  446  1067  Person
# 3  imgs/train/bookstore_video0_40.jpg  587   976  626  1013  Person
# 4  imgs/train/bookstore_video0_40.jpg  895   253  949   303  Person

# %%
os.makedirs("humans", exist_ok=True)
df2 = pd.DataFrame(df)

# %%
def show_image_objects(image_row):

  img_path = 'imgs/test/bookstore_video1_8100.jpg'
  box = [
    991 , 854, 1021, 883
  ]

  image = read_image_bgr(img_path)

  draw = image.copy()
  draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

  draw_box(draw, box, color=(255, 255, 0))

  plt.axis('off')
  plt.imshow(draw)
  plt.show()

# %%
show_image_objects(df.iloc[0])

# %% [markdown]
# #Training phase

# %%
train_df, test_df = train_test_split(df2, test_size=0.0001, random_state=RANDOM_SEED)
train_df.head()
# Out:
#            imgs/train/bookstore_video0_40.jpg   763   899   806   940  Person
# 30845        imgs/train/hyang_video5_8760.jpg  1132   991  1209  1099   Biker
# 1662     imgs/train/bookstore_video0_4080.jpg   895   691   947   723  Person
# 15731  imgs/train/deathCircle_video0_3480.jpg   957  1176  1039  1258   Biker
# 13904   imgs/train/deathCircle_video0_800.jpg   835  1741   878  1814   Biker
# 1786     imgs/train/bookstore_video0_4320.jpg   931   693   979   725  Person

# %%
compression_opts = dict(method='zip',
                        archive_name='train.csv')  
train_df.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
# !unzip out.zip
# Out:
# Archive:  out.zip
#   inflating: train.csv

# %%
ANNOTATIOS_FILE = 'train_annotations.csv'
CLASSES_FILE = 'classes.csv'

train_df.to_csv(ANNOTATIOS_FILE,index=False, header=None)

classes = set(['Person', 'Biker', 'Car', 'Bus'])

with open(CLASSES_FILE, 'w') as f:
	for i, line in enumerate(sorted(classes)):
		f.write('{}, {}\n'.format(line,i))

# %%
# !head classes.csv
# Out:
# Biker, 0
# Bus, 1
# Car, 2
# Person, 3

# %%
def count_files(path):
    return sum([len(files) for _, _, files in os.walk(path)])

count_files('/content/keras-retinanet/imgs/train')
# Out:
# 2612

# %%
# !wc -l train_annotations.csv
# Out:
# 35673 train_annotations.csv

# %%
# !shuf -o shuffled-file1.csv < train_annotations.csv

# %%
# !keras_retinanet/bin/train.py \
--initial-epoch 65 \
--epochs 85 \
--steps 740 \
--batch-size 4 \
--config config.ini \
--snapshot snapshots/resnet50_csv_65.h5 \
csv train_annotations.csv classes.csv
# Out:
# 2021-05-25 14:38:43.508348: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Loading model, this may take a second...
# 2021-05-25 14:38:45.255135: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-25 14:38:45.308884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:45.309523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-25 14:38:45.309563: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 14:38:45.493947: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-25 14:38:45.601468: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-25 14:38:45.619264: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-25 14:38:45.826136: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-25 14:38:45.843564: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-25 14:38:46.217463: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 14:38:46.217646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.218325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.218828: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-25 14:38:46.219147: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-25 14:38:46.224145: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2199995000 Hz
# 2021-05-25 14:38:46.224411: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5556678f9100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 14:38:46.224444: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-25 14:38:46.467532: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.468320: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5556678f9640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 14:38:46.468352: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-05-25 14:38:46.468573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.469120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-25 14:38:46.469155: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 14:38:46.469213: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-25 14:38:46.469240: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-25 14:38:46.469254: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-25 14:38:46.469266: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-25 14:38:46.469279: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-25 14:38:46.469292: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 14:38:46.469350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.469892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.470397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-25 14:38:46.470439: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 14:38:46.888086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-25 14:38:46.888146: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-05-25 14:38:46.888154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-05-25 14:38:46.888360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.888981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 14:38:46.889516: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-25 14:38:46.889559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14958 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 4)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,500,512
# Trainable params: 36,394,272
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From keras_retinanet/bin/train.py:548: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 66/85
# 2021-05-25 14:38:55.184823: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 14:38:57.572585: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 303/740 [===========>..................] - ETA: 4:55 - loss: 0.5527 - regression_loss: 0.4817 - classification_loss: 0.07102021-05-25 14:42:27.147449: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-05-25 14:42:27.154121: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 740/740 [==============================] - ETA: 0s - loss: 0.5642 - regression_loss: 0.4907 - classification_loss: 0.0734
# Epoch 00066: saving model to ./snapshots/resnet50_csv_66.h5
# 740/740 [==============================] - 491s 663ms/step - loss: 0.5642 - regression_loss: 0.4907 - classification_loss: 0.0734
# Epoch 67/85
# 740/740 [==============================] - ETA: 0s - loss: 0.5481 - regression_loss: 0.4777 - classification_loss: 0.0703
# Epoch 00067: saving model to ./snapshots/resnet50_csv_67.h5
# 740/740 [==============================] - 474s 641ms/step - loss: 0.5481 - regression_loss: 0.4777 - classification_loss: 0.0703
# Epoch 68/85
# 740/740 [==============================] - ETA: 0s - loss: 0.5456 - regression_loss: 0.4761 - classification_loss: 0.0695
# Epoch 00068: saving model to ./snapshots/resnet50_csv_68.h5
# 740/740 [==============================] - 473s 639ms/step - loss: 0.5456 - regression_loss: 0.4761 - classification_loss: 0.0695
# Epoch 69/85
# 740/740 [==============================] - ETA: 0s - loss: 0.5328 - regression_loss: 0.4654 - classification_loss: 0.0674
# Epoch 00069: saving model to ./snapshots/resnet50_csv_69.h5
# 740/740 [==============================] - 474s 641ms/step - loss: 0.5328 - regression_loss: 0.4654 - classification_loss: 0.0674
# Epoch 70/85
# 740/740 [==============================] - ETA: 0s - loss: 0.5347 - regression_loss: 0.4679 - classification_loss: 0.0668
# Epoch 00070: saving model to ./snapshots/resnet50_csv_70.h5
# 740/740 [==============================] - 474s 641ms/step - loss: 0.5347 - regression_loss: 0.4679 - classification_loss: 0.0668
None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 4)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,500,512
# Trainable params: 36,394,272
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From keras_retinanet/bin/train.py:548: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 46/65
# 2021-05-25 10:19:58.098866: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 10:20:00.477483: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 140/740 [====>.........................] - ETA: 7:28 - loss: 0.7504 - regression_loss: 0.6416 - classification_loss: 0.10872021-05-25 10:21:49.454492: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-05-25 10:21:49.461513: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 740/740 [==============================] - ETA: 0s - loss: 0.7690 - regression_loss: 0.6550 - classification_loss: 0.1140
# Epoch 00046: saving model to ./snapshots/resnet50_csv_46.h5
# 740/740 [==============================] - 513s 694ms/step - loss: 0.7690 - regression_loss: 0.6550 - classification_loss: 0.1140
# Epoch 47/65
# 740/740 [==============================] - ETA: 0s - loss: 0.7475 - regression_loss: 0.6356 - classification_loss: 0.1118
# Epoch 00057: saving model to ./snapshots/resnet50_csv_57.h5
# 740/740 [==============================] - 501s 678ms/step - loss: 0.6419 - regression_loss: 0.5531 - classification_loss: 0.0888
# Epoch 58/65
# 740/740 [==============================] - ETA: 0s - loss: 0.6203 - regression_loss: 0.5345 - classification_loss: 0.0858
# Epoch 00058: saving model to ./snapshots/resnet50_csv_58.h5
# 740/740 [==============================] - 496s 671ms/step - loss: 0.6203 - regression_loss: 0.5345 - classification_loss: 0.0858
# Epoch 59/65
# 740/740 [==============================] - ETA: 0s - loss: 0.6177 - regression_loss: 0.5325 - classification_loss: 0.0852
# Epoch 00059: saving model to ./snapshots/resnet50_csv_59.h5
# 740/740 [==============================] - 495s 669ms/step - loss: 0.6177 - regression_loss: 0.5325 - classification_loss: 0.0852
# Epoch 60/65
# 740/740 [==============================] - ETA: 0s - loss: 0.6004 - regression_loss: 0.5185 - classification_loss: 0.0819
# Epoch 00060: saving model to ./snapshots/resnet50_csv_60.h5
# 740/740 [==============================] - 490s 663ms/step - loss: 0.6004 - regression_loss: 0.5185 - classification_loss: 0.0819
# Epoch 61/65
# 740/740 [==============================] - ETA: 0s - loss: 0.6017 - regression_loss: 0.5204 - classification_loss: 0.0813
# Epoch 00061: saving model to ./snapshots/resnet50_csv_61.h5
# 740/740 [==============================] - 490s 662ms/step - loss: 0.6017 - regression_loss: 0.5204 - classification_loss: 0.0813
# Epoch 62/65
# 740/740 [==============================] - ETA: 0s - loss: 0.5905 - regression_loss: 0.5112 - classification_loss: 0.0793
# Epoch 00062: saving model to ./snapshots/resnet50_csv_62.h5
# 740/740 [==============================] - 493s 666ms/step - loss: 0.5905 - regression_loss: 0.5112 - classification_loss: 0.0793
# Epoch 63/65
# 740/740 [==============================] - ETA: 0s - loss: 0.5817 - regression_loss: 0.5052 - classification_loss: 0.0765
# Epoch 00063: saving model to ./snapshots/resnet50_csv_63.h5
# 740/740 [==============================] - 492s 665ms/step - loss: 0.5817 - regression_loss: 0.5052 - classification_loss: 0.0765
# Epoch 64/65
# 740/740 [==============================] - ETA: 0s - loss: 0.5740 - regression_loss: 0.4983 - classification_loss: 0.0756
# Epoch 00064: saving model to ./snapshots/resnet50_csv_64.h5
# 740/740 [==============================] - 488s 659ms/step - loss: 0.5740 - regression_loss: 0.4983 - classification_loss: 0.0756
# Epoch 65/65
# 740/740 [==============================] - ETA: 0s - loss: 0.5698 - regression_loss: 0.4956 - classification_loss: 0.0743
# Epoch 00065: saving model to ./snapshots/resnet50_csv_65.h5
# 740/740 [==============================] - 487s 658ms/step - loss: 0.5698 - regression_loss: 0.4956 - classification_loss: 0.0743

# %%
# !keras_retinanet/bin/train.py \
--initial-epoch 40 \
--epochs 60 \
--steps 740 \
--batch-size 4 \
--config config.ini \
--snapshot snapshots/resnet50_csv_40.h5 \
csv train_annotations.csv classes.csv
# Out:
# 2021-05-24 15:52:28.522738: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Loading model, this may take a second...
# 2021-05-24 15:52:31.016087: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-24 15:52:31.041254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.042175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 15:52:31.042218: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 15:52:31.044010: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 15:52:31.045995: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 15:52:31.046419: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 15:52:31.048933: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 15:52:31.050003: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 15:52:31.055603: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 15:52:31.055739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.056689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.057565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 15:52:31.057927: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-24 15:52:31.063808: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2299995000 Hz
# 2021-05-24 15:52:31.064096: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555cceef0bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 15:52:31.064132: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-24 15:52:31.254378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.255421: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555cceef0d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 15:52:31.255455: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-05-24 15:52:31.255682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.256494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 15:52:31.256537: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 15:52:31.256604: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 15:52:31.256637: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 15:52:31.256662: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 15:52:31.256689: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 15:52:31.256720: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 15:52:31.256744: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 15:52:31.256809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.257798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.258561: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 15:52:31.258622: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 15:52:31.712120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-24 15:52:31.712205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-05-24 15:52:31.712218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-05-24 15:52:31.712434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.713354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 15:52:31.714201: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-24 15:52:31.714268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14958 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 4)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,500,512
# Trainable params: 36,394,272
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From keras_retinanet/bin/train.py:548: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 41/60
# 2021-05-24 15:52:41.966651: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 15:52:42.789044: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 431/740 [================>.............] - ETA: 3:35 - loss: 0.8507 - regression_loss: 0.7201 - classification_loss: 0.13062021-05-24 15:57:47.873348: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-05-24 15:57:47.880504: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 740/740 [==============================] - ETA: 0s - loss: 0.8389 - regression_loss: 0.7102 - classification_loss: 0.1287
# Epoch 00041: saving model to ./snapshots/resnet50_csv_41.h5
# 740/740 [==============================] - 515s 696ms/step - loss: 0.8389 - regression_loss: 0.7102 - classification_loss: 0.1287
# Epoch 42/60
# 740/740 [==============================] - ETA: 0s - loss: 0.8240 - regression_loss: 0.6991 - classification_loss: 0.1249
# Epoch 00042: saving model to ./snapshots/resnet50_csv_42.h5
# 740/740 [==============================] - 497s 671ms/step - loss: 0.8240 - regression_loss: 0.6991 - classification_loss: 0.1249
# Epoch 43/60
# 740/740 [==============================] - ETA: 0s - loss: 0.8125 - regression_loss: 0.6896 - classification_loss: 0.1230
# Epoch 00043: saving model to ./snapshots/resnet50_csv_43.h5
# 740/740 [==============================] - 493s 667ms/step - loss: 0.8125 - regression_loss: 0.6896 - classification_loss: 0.1230
# Epoch 44/60
# 740/740 [==============================] - ETA: 0s - loss: 0.7965 - regression_loss: 0.6771 - classification_loss: 0.1195
# Epoch 00044: saving model to ./snapshots/resnet50_csv_44.h5
# 740/740 [==============================] - 491s 664ms/step - loss: 0.7965 - regression_loss: 0.6771 - classification_loss: 0.1195
# Epoch 45/60
# 740/740 [==============================] - ETA: 0s - loss: 0.7732 - regression_loss: 0.6572 - classification_loss: 0.1160
# Epoch 00045: saving model to ./snapshots/resnet50_csv_45.h5
# 740/740 [==============================] - 500s 676ms/step - loss: 0.7732 - regression_loss: 0.6572 - classification_loss: 0.1160
# Epoch 46/60
#  27/740 [>.............................] - ETA: 7:50 - loss: 0.8297 - regression_loss: 0.7010 - classification_loss: 0.1287Traceback (most recent call last):
#   File "keras_retinanet/bin/train.py", line 553, in <module>
#     main()
#   File "keras_retinanet/bin/train.py", line 548, in main
#     initial_epoch=args.initial_epoch
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py", line 1829, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py", line 108, in _method_wrapper
#     return method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py", line 1098, in fit
#     tmp_logs = train_function(iterator)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 780, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py", line 814, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 2829, in __call__
#     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 1848, in _filtered_call
#     cancellation_manager=cancellation_manager)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 1924, in _call_flat
#     ctx, args, cancellation_manager=cancellation_manager))
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py", line 550, in call
#     ctx=ctx)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
#     inputs, attrs, num_outputs)
# KeyboardInterrupt
# ^C

# %%
# !keras_retinanet/bin/train.py \
--initial-epoch 20 \
--epochs 40 \
--steps 740 \
--batch-size 4 \
--config config.ini \
--snapshot snapshots/resnet50_csv_20.h5 \
csv train_annotations.csv classes.csv
# Out:
# 2021-05-24 13:06:44.723375: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Loading model, this may take a second...
# 2021-05-24 13:06:46.926525: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-24 13:06:46.950644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:46.951640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 13:06:46.951688: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 13:06:46.953611: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 13:06:46.958920: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 13:06:46.959321: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 13:06:46.963566: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 13:06:46.964621: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 13:06:46.969118: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 13:06:46.969223: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:46.970240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:46.971067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 13:06:46.971424: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-24 13:06:46.976959: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2299995000 Hz
# 2021-05-24 13:06:46.977270: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f5de446bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 13:06:46.977319: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-24 13:06:47.176831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.178076: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f5de446d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 13:06:47.178161: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-05-24 13:06:47.178466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.179550: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 13:06:47.179602: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 13:06:47.179714: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 13:06:47.179755: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 13:06:47.179792: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 13:06:47.179828: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 13:06:47.179862: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 13:06:47.179895: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 13:06:47.179990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.180915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.181735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 13:06:47.181785: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 13:06:47.625464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-24 13:06:47.625527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-05-24 13:06:47.625582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-05-24 13:06:47.625839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.626777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 13:06:47.627609: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-24 13:06:47.627687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14958 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 4)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,500,512
# Trainable params: 36,394,272
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From keras_retinanet/bin/train.py:548: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 21/40
# 2021-05-24 13:06:57.736369: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 13:06:58.518446: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 345/740 [============>.................] - ETA: 4:36 - loss: 1.3779 - regression_loss: 1.1659 - classification_loss: 0.21212021-05-24 13:11:04.101074: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-05-24 13:11:04.108046: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 740/740 [==============================] - ETA: 0s - loss: 1.3725 - regression_loss: 1.1605 - classification_loss: 0.2120
# Epoch 00021: saving model to ./snapshots/resnet50_csv_21.h5
# 740/740 [==============================] - 507s 685ms/step - loss: 1.3725 - regression_loss: 1.1605 - classification_loss: 0.2120
# Epoch 22/40
# 740/740 [==============================] - ETA: 0s - loss: 1.3276 - regression_loss: 1.1208 - classification_loss: 0.2068
# Epoch 00022: saving model to ./snapshots/resnet50_csv_22.h5
# 740/740 [==============================] - 489s 661ms/step - loss: 1.3276 - regression_loss: 1.1208 - classification_loss: 0.2068
# Epoch 23/40
# 740/740 [==============================] - ETA: 0s - loss: 1.2938 - regression_loss: 1.0922 - classification_loss: 0.2016
# Epoch 00023: saving model to ./snapshots/resnet50_csv_23.h5
# 740/740 [==============================] - 490s 662ms/step - loss: 1.2938 - regression_loss: 1.0922 - classification_loss: 0.2016
# Epoch 24/40
# 740/740 [==============================] - ETA: 0s - loss: 1.2550 - regression_loss: 1.0590 - classification_loss: 0.1960
# Epoch 00024: saving model to ./snapshots/resnet50_csv_24.h5
# 740/740 [==============================] - 492s 664ms/step - loss: 1.2550 - regression_loss: 1.0590 - classification_loss: 0.1960
# Epoch 25/40
# 740/740 [==============================] - ETA: 0s - loss: 1.2237 - regression_loss: 1.0319 - classification_loss: 0.1919
# Epoch 00025: saving model to ./snapshots/resnet50_csv_25.h5
# 740/740 [==============================] - 488s 660ms/step - loss: 1.2237 - regression_loss: 1.0319 - classification_loss: 0.1919
# Epoch 26/40
# 740/740 [==============================] - ETA: 0s - loss: 1.1828 - regression_loss: 0.9975 - classification_loss: 0.1852
# Epoch 00026: saving model to ./snapshots/resnet50_csv_26.h5
# 740/740 [==============================] - 489s 660ms/step - loss: 1.1828 - regression_loss: 0.9975 - classification_loss: 0.1852
# Epoch 27/40
# 740/740 [==============================] - ETA: 0s - loss: 1.1527 - regression_loss: 0.9717 - classification_loss: 0.1811
# Epoch 00027: saving model to ./snapshots/resnet50_csv_27.h5
# 740/740 [==============================] - 489s 660ms/step - loss: 1.1527 - regression_loss: 0.9717 - classification_loss: 0.1811
# Epoch 28/40
# 740/740 [==============================] - ETA: 0s - loss: 0.8966 - regression_loss: 0.7584 - classification_loss: 0.1382
# Epoch 00038: saving model to ./snapshots/resnet50_csv_38.h5
# 740/740 [==============================] - 489s 661ms/step - loss: 0.8966 - regression_loss: 0.7584 - classification_loss: 0.1382
# Epoch 39/40
# 740/740 [==============================] - ETA: 0s - loss: 0.8793 - regression_loss: 0.7439 - classification_loss: 0.1354
# Epoch 00039: saving model to ./snapshots/resnet50_csv_39.h5
# 740/740 [==============================] - 485s 656ms/step - loss: 0.8793 - regression_loss: 0.7439 - classification_loss: 0.1354
# Epoch 40/40
# 740/740 [==============================] - ETA: 0s - loss: 0.8586 - regression_loss: 0.7263 - classification_loss: 0.1323
# Epoch 00040: saving model to ./snapshots/resnet50_csv_40.h5
# 740/740 [==============================] - 485s 655ms/step - loss: 0.8586 - regression_loss: 0.7263 - classification_loss: 0.1323

# %%
# !keras_retinanet/bin/train.py \
--epochs 20 \
--steps 740 \
--batch-size 4 \
--config config.ini \
--weights snapshots/resnet50_coco_best_v2.1.0.h5 \
csv train_annotations.csv classes.csv
# Out:
# 2021-05-24 10:17:47.815163: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# Creating model, this may take a second...
# 2021-05-24 10:17:49.786256: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-24 10:17:49.811770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:49.812844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 10:17:49.812887: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 10:17:49.814963: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 10:17:49.817008: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 10:17:49.817420: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 10:17:49.819548: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 10:17:49.820637: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 10:17:49.825024: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 10:17:49.825174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:49.826053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:49.827016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 10:17:49.827339: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-24 10:17:49.833178: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2299995000 Hz
# 2021-05-24 10:17:49.833527: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56004613ea00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 10:17:49.833565: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-24 10:17:50.029296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.030453: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56004613ebc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-24 10:17:50.030498: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-05-24 10:17:50.030767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.031880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-05-24 10:17:50.031945: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 10:17:50.032018: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-24 10:17:50.032113: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-24 10:17:50.032158: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-24 10:17:50.032209: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-24 10:17:50.032255: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-24 10:17:50.032315: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 10:17:50.032449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.033672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.034736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-05-24 10:17:50.034816: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-24 10:17:50.513610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-24 10:17:50.513668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-05-24 10:17:50.513695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-05-24 10:17:50.513984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.514912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-24 10:17:50.515744: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-24 10:17:50.515791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14958 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:Skipping loading of weights for layer regression_submodel due to mismatch in shape ((3, 3, 256, 48) vs (3, 3, 256, 36)).
# WARNING:tensorflow:Skipping loading of weights for layer regression_submodel due to mismatch in shape ((48,) vs (36,)).
# WARNING:tensorflow:Skipping loading of weights for layer classification_submodel due to mismatch in shape ((3, 3, 256, 48) vs (3, 3, 256, 720)).
# WARNING:tensorflow:Skipping loading of weights for layer classification_submodel due to mismatch in shape ((48,) vs (720,)).
# Model: "retinanet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, None, None, 6 0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, None, None, 2 0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, None, None, 6 0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, None, None, 2 0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, None, None, 6 0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, None, None, 2 0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, None, None, 1 0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, None, None, 5 0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, None, None, 1 0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, None, None, 5 0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, None, None, 1 0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, None, None, 5 0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, None, None, 1 0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, None, None, 5 0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, None, None, 2 0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, None, None, 1 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, None, None, 2 0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, None, None, 1 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, None, None, 2 0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, None, None, 1 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, None, None, 2 0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, None, None, 1 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, None, None, 2 0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, None, None, 1 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, None, None, 2 0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# res4f (Add)                     (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  res4e_relu[0][0]
# __________________________________________________________________________________________________
# res4f_relu (Activation)         (None, None, None, 1 0           res4f[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524288      res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, None, None, 5 0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2097152     res4f_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, None, None, 2 0           res5a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b_branch2b (ZeroPadding (None, None, None, 5 0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, None, None, 2 0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5c_branch2b (ZeroPadding (None, None, None, 5 0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359296     padding5c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, None, None, 2 0           res5c[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 524544      res5c_relu[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  res4f_relu[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 262400      res4f_relu[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  res3d_relu[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 131328      res3d_relu[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 4718848     res5c_relu[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Functional (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Functi (None, None, 4)      2470960     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[0][0]
#                                                                  regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 4)      0           classification_submodel[0][0]
#                                                                  classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
# ==================================================================================================
# Total params: 36,500,512
# Trainable params: 36,394,272
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From keras_retinanet/bin/train.py:548: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 2021-05-24 10:18:04.123411: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-24 10:18:04.937745: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
#  43/740 [>.............................] - ETA: 10:51 - loss: 3.9303 - regression_loss: 2.8260 - classification_loss: 1.10432021-05-24 10:18:49.172704: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-05-24 10:18:49.179677: W tensorflow/core/common_runtime/bfc_allocator.cc:246] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 740/740 [==============================] - ETA: 0s - loss: 2.9913 - regression_loss: 2.4112 - classification_loss: 0.5802
# Epoch 00001: saving model to ./snapshots/resnet50_csv_01.h5
# 740/740 [==============================] - 513s 693ms/step - loss: 2.9913 - regression_loss: 2.4112 - classification_loss: 0.5802
# Epoch 2/20
# 740/740 [==============================] - ETA: 0s - loss: 2.4870 - regression_loss: 2.0782 - classification_loss: 0.4088
# Epoch 00002: saving model to ./snapshots/resnet50_csv_02.h5
# 740/740 [==============================] - 494s 668ms/step - loss: 2.4870 - regression_loss: 2.0782 - classification_loss: 0.4088
# Epoch 3/20
# 740/740 [==============================] - ETA: 0s - loss: 2.3148 - regression_loss: 1.9476 - classification_loss: 0.3672
# Epoch 00003: saving model to ./snapshots/resnet50_csv_03.h5
# 740/740 [==============================] - 494s 668ms/step - loss: 2.3148 - regression_loss: 1.9476 - classification_loss: 0.3672
# Epoch 4/20
# 740/740 [==============================] - ETA: 0s - loss: 2.2159 - regression_loss: 1.8717 - classification_loss: 0.3442
# Epoch 00004: saving model to ./snapshots/resnet50_csv_04.h5
# 740/740 [==============================] - 497s 671ms/step - loss: 2.2159 - regression_loss: 1.8717 - classification_loss: 0.3442
# Epoch 5/20
# 740/740 [==============================] - ETA: 0s - loss: 2.1392 - regression_loss: 1.8109 - classification_loss: 0.3283
# Epoch 00005: saving model to ./snapshots/resnet50_csv_05.h5
# 740/740 [==============================] - 496s 670ms/step - loss: 2.1392 - regression_loss: 1.8109 - classification_loss: 0.3283
# Epoch 6/20
# 740/740 [==============================] - ETA: 0s - loss: 2.0726 - regression_loss: 1.7571 - classification_loss: 0.3155
# Epoch 00006: saving model to ./snapshots/resnet50_csv_06.h5
# 740/740 [==============================] - 496s 670ms/step - loss: 2.0726 - regression_loss: 1.7571 - classification_loss: 0.3155
# Epoch 7/20
# 740/740 [==============================] - ETA: 0s - loss: 2.0144 - regression_loss: 1.7111 - classification_loss: 0.3033
# Epoch 00007: saving model to ./snapshots/resnet50_csv_07.h5
# 740/740 [==============================] - 495s 669ms/step - loss: 1.5241 - regression_loss: 1.2906 - classification_loss: 0.2335
# Epoch 18/20
# 740/740 [==============================] - ETA: 0s - loss: 1.4829 - regression_loss: 1.2548 - classification_loss: 0.2281
# Epoch 00018: saving model to ./snapshots/resnet50_csv_18.h5
# 740/740 [==============================] - 495s 668ms/step - loss: 1.4829 - regression_loss: 1.2548 - classification_loss: 0.2281
# Epoch 19/20
# 740/740 [==============================] - ETA: 0s - loss: 1.4391 - regression_loss: 1.2172 - classification_loss: 0.2219
# Epoch 00019: saving model to ./snapshots/resnet50_csv_19.h5
# 740/740 [==============================] - 495s 669ms/step - loss: 1.4391 - regression_loss: 1.2172 - classification_loss: 0.2219
# Epoch 20/20
# 740/740 [==============================] - ETA: 0s - loss: 1.4005 - regression_loss: 1.1842 - classification_loss: 0.2163
# Epoch 00020: saving model to ./snapshots/resnet50_csv_20.h5
# 740/740 [==============================] - 495s 669ms/step - loss: 1.4005 - regression_loss: 1.1842 - classification_loss: 0.2163

# %%
list = os.listdir("imgs/test") # dir is your directory path
number_files = len(list)
print(number_files)
# Out:
# 665

# %% [markdown]
# Train the RetinaNet using own dataset

# %% [markdown]
# #Inference model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -r /content/keras-retinanet/snapshots/resnet50_csv_85.h5 /content/gdrive/MyDrive/HereIdiot/

# %%
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
from tensorflow import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import tensorflow.keras.backend
# use this to change which GPU to use
# gpu = 0

# # set the modified tf session as backend in keras
# setup_gpu(gpu)

# %%
model_path = os.path.join('snapshots', sorted(os.listdir('snapshots'), reverse=True)[0])
print(model_path)
# Out:
# snapshots/resnet50_csv_85.h5

# %% [markdown]
# #Compilation of the model

# %%
import tensorflow as tf
from tensorflow import keras
keras.__version__
# Out:
# '2.4.0'

# %%
# !keras_retinanet/bin/convert_model.py --config config.ini snapshots/resnet50_csv_85.h5 snapshots/inference.h5
# Out:
# 2021-06-28 13:48:36.873034: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-28 13:48:37.956225: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-28 13:48:38.007678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 13:48:38.008286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-06-28 13:48:38.008323: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-28 13:48:38.209022: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-06-28 13:48:38.318875: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-06-28 13:48:38.339759: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-06-28 13:48:38.536637: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-06-28 13:48:38.571234: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-06-28 13:48:38.967064: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-06-28 13:48:38.967240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 13:48:38.967927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 13:48:38.968443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# Using TensorFlow backend.
# 2021-06-28 13:48:39.208222: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-28 13:48:39.213445: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2199995000 Hz
# 2021-06-28 13:48:39.213758: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d87668ed80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-06-28 13:48:39.213790: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-06-28 13:48:39.215035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-28 13:48:39.215066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]

# %%
import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu


model_path = os.path.join( 'snapshots', 'inference.h5')
model = models.load_model(model_path, backbone_name='resnet50')
# model = models.convert_model(model)
# keras_retinanet.models.backbone('resnet50').retinanet(num_classes=1)
# model.compile(
#     loss={
#         'regression'    : keras_retinanet.losses.smooth_l1(),
#         'classification': keras_retinanet.losses.focal()
#     },
#     optimizer=keras.optimizers.Adam(lr=1e-5, clipnorm=0.001),
#     metrics=['accuracy']
# )

# labels_to_names = pd.read_csv(CLASSES_FILE, header=None).T.loc[0].to_dict()
labels_to_names ={0: 'Biker', 1: 'Bus', 2: 'Car', 3: 'Person'}
print(labels_to_names)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# {0: 'Biker', 1: 'Bus', 2: 'Car', 3: 'Person'}

# %%
from IPython.display import SVG
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model.png')

# %% [markdown]
# #Run model on an image

# %%
annotations_file = 'test_annotations.csv'
cwd = os.getcwd()

image_names = []

with open (os.path.join(cwd, annotations_file)) as csvfile:
    readCSV = csv.reader(csvfile, delimiter='\n')
    for row in readCSV:
        vals = row[0].split(',')
        this_filepath = vals[0]
        image_names.append(this_filepath)
        
## remove duplicates by taking a set
# imagePaths = list(set(image_names))
# print(len(imagePaths))

LABELS = open('classes.csv').read().strip().split('\n')
LABELS = {int(L.split(",")[1]): L.split(",")[0] for L in LABELS}

# for(i, imagePath) in enumerate(imagePaths):
  
# filename = (imagePath.split(os.path.sep)[-1]).split('.')[0]
# output_file = os.path.sep.join(['humans', '{}.txt'.format(filename)])
# file = open(output_file, 'w')

image = read_image_bgr('imgs/test/little_video1_8100.jpg' )

# copy to draw on
draw = image.copy()
draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
image = preprocess_image(image)
image, scale = resize_image(image)

# process image
start = time.time()
(boxes, scores, labels) = model.predict(np.expand_dims(image, axis=0))
print("processing time: ", time.time() - start)

# correct for image scale
boxes /= scale

# visualize detections
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
    if score < 0.4:
        break
        
    color = label_color(label)
    
    b = box.astype(int)
    row = " ".join([LABELS[label], str(score),
                      str(box[1]), str(box[0]), str(box[3]), str(box[2])])
    # file.write("{}\n".format(row))
    draw_box(draw, b, color=color)
    
    caption = "{} {:.3f}".format(labels_to_names[label], score)
    draw_caption(draw, b, caption)
    
# file.close()
plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(draw)
plt.show()
# Out:
# processing time:  2.2783079147338867

# %%
annotations_file = 'test_annotations_sorted.csv'
cwd = os.getcwd()

image_names = []

with open (os.path.join(cwd, annotations_file)) as csvfile:
    readCSV = csv.reader(csvfile, delimiter='\n')
    for row in readCSV:
        vals = row[0].split(',')
        this_filepath = vals[0]
        image_names.append(this_filepath)
        
## remove duplicates by taking a set
image_names = list(set(image_names))
print(len(image_names))
# Out:
# 663

# %%
image_names.sort()

# %%
image_names
# Out:
# ['imgs/test/bookstore_video1_10020.jpg',
#  'imgs/test/bookstore_video1_10050.jpg',
#  'imgs/test/bookstore_video1_10080.jpg',
#  'imgs/test/bookstore_video1_10110.jpg',
#  'imgs/test/bookstore_video1_10140.jpg',
#  'imgs/test/bookstore_video1_10170.jpg',
#  'imgs/test/bookstore_video1_10200.jpg',
#  'imgs/test/bookstore_video1_10230.jpg',
#  'imgs/test/bookstore_video1_10260.jpg',
#  'imgs/test/bookstore_video1_10290.jpg',
#  'imgs/test/bookstore_video1_10320.jpg',
#  'imgs/test/bookstore_video1_10350.jpg',
#  'imgs/test/bookstore_video1_10380.jpg',
#  'imgs/test/bookstore_video1_10410.jpg',
#  'imgs/test/bookstore_video1_10440.jpg',
#  'imgs/test/bookstore_video1_10470.jpg',
#  'imgs/test/bookstore_video1_10500.jpg',
#  'imgs/test/bookstore_video1_10530.jpg',
#  'imgs/test/bookstore_video1_10560.jpg',
#  'imgs/test/bookstore_video1_10590.jpg',
#  'imgs/test/bookstore_video1_10620.jpg',
#  'imgs/test/bookstore_video1_10650.jpg',
#  'imgs/test/bookstore_video1_10680.jpg',
#  'imgs/test/bookstore_video1_10710.jpg',
#  'imgs/test/bookstore_video1_10740.jpg',
#  'imgs/test/bookstore_video1_10770.jpg',
#  'imgs/test/bookstore_video1_10800.jpg',
#  'imgs/test/bookstore_video1_10830.jpg',
#  'imgs/test/bookstore_video1_10860.jpg',
#  'imgs/test/bookstore_video1_10890.jpg',
#  'imgs/test/bookstore_video1_10920.jpg',
#  'imgs/test/bookstore_video1_10950.jpg',
#  'imgs/test/bookstore_video1_10980.jpg',
#  'imgs/test/bookstore_video1_11010.jpg',
#  'imgs/test/bookstore_video1_11040.jpg',
#  'imgs/test/bookstore_video1_11070.jpg',
#  'imgs/test/bookstore_video1_11100.jpg',
#  'imgs/test/bookstore_video1_11130.jpg',
#  'imgs/test/bookstore_video1_11160.jpg',
#  'imgs/test/bookstore_video1_11190.jpg',
#  'imgs/test/bookstore_video1_11220.jpg',
#  'imgs/test/bookstore_video1_11250.jpg',
#  'imgs/test/bookstore_video1_11280.jpg',
#  'imgs/test/bookstore_video1_11310.jpg',
#  'imgs/test/bookstore_video1_11340.jpg',
#  'imgs/test/bookstore_video1_11370.jpg',
#  'imgs/test/bookstore_video1_11400.jpg',
#  'imgs/test/bookstore_video1_11430.jpg',
#  'imgs/test/bookstore_video1_11460.jpg',
#  'imgs/test/bookstore_video1_11490.jpg',
#  'imgs/test/bookstore_video1_11520.jpg',
#  'imgs/test/bookstore_video1_11550.jpg',
#  'imgs/test/bookstore_video1_11580.jpg',
#  'imgs/test/bookstore_video1_11610.jpg',
#  'imgs/test/bookstore_video1_11640.jpg',
#  'imgs/test/bookstore_video1_11670.jpg',
#  'imgs/test/bookstore_video1_11700.jpg',
#  'imgs/test/bookstore_video1_11730.jpg',
#  'imgs/test/bookstore_video1_11760.jpg',
#  'imgs/test/bookstore_video1_11790.jpg',
#  'imgs/test/bookstore_video1_11820.jpg',
#  'imgs/test/bookstore_video1_11850.jpg',
#  'imgs/test/bookstore_video1_11880.jpg',
#  'imgs/test/bookstore_video1_11910.jpg',
#  'imgs/test/bookstore_video1_11940.jpg',
#  'imgs/test/bookstore_video1_11970.jpg',
#  'imgs/test/bookstore_video1_12000.jpg',
#  'imgs/test/bookstore_video1_12030.jpg',
#  'imgs/test/bookstore_video1_12060.jpg',
#  'imgs/test/bookstore_video1_12090.jpg',
#  'imgs/test/bookstore_video1_12120.jpg',
#  'imgs/test/bookstore_video1_12150.jpg',
#  'imgs/test/bookstore_video1_12180.jpg',
#  'imgs/test/bookstore_video1_12210.jpg',
#  'imgs/test/bookstore_video1_12240.jpg',
#  'imgs/test/bookstore_video1_12270.jpg',
#  'imgs/test/bookstore_video1_12300.jpg',
#  'imgs/test/bookstore_video1_12330.jpg',
#  'imgs/test/bookstore_video1_12360.jpg',
#  'imgs/test/bookstore_video1_12390.jpg',
#  'imgs/test/bookstore_video1_12420.jpg',
#  'imgs/test/bookstore_video1_12450.jpg',
#  'imgs/test/bookstore_video1_12480.jpg',
#  'imgs/test/bookstore_video1_12510.jpg',
#  'imgs/test/bookstore_video1_12540.jpg',
#  'imgs/test/bookstore_video1_12570.jpg',
#  'imgs/test/bookstore_video1_12600.jpg',
#  'imgs/test/bookstore_video1_12630.jpg',
#  'imgs/test/bookstore_video1_12660.jpg',
#  'imgs/test/bookstore_video1_12690.jpg',
#  'imgs/test/bookstore_video1_12720.jpg',
#  'imgs/test/bookstore_video1_12750.jpg',
#  'imgs/test/bookstore_video1_12780.jpg',
#  'imgs/test/bookstore_video1_12810.jpg',
#  'imgs/test/bookstore_video1_12840.jpg',
#  'imgs/test/bookstore_video1_12870.jpg',
#  'imgs/test/bookstore_video1_12900.jpg',
#  'imgs/test/bookstore_video1_12930.jpg',
#  'imgs/test/bookstore_video1_12960.jpg',
#  'imgs/test/bookstore_video1_12990.jpg',
#  'imgs/test/bookstore_video1_13020.jpg',
#  'imgs/test/bookstore_video1_13050.jpg',
#  'imgs/test/bookstore_video1_13080.jpg',
#  'imgs/test/bookstore_video1_13110.jpg',
#  'imgs/test/bookstore_video1_13140.jpg',
#  'imgs/test/bookstore_video1_13170.jpg',
#  'imgs/test/bookstore_video1_13200.jpg',
#  'imgs/test/bookstore_video1_13230.jpg',
#  'imgs/test/bookstore_video1_13260.jpg',
#  'imgs/test/bookstore_video1_13290.jpg',
#  'imgs/test/bookstore_video1_13320.jpg',
#  'imgs/test/bookstore_video1_13350.jpg',
#  'imgs/test/bookstore_video1_13380.jpg',
#  'imgs/test/bookstore_video1_13410.jpg',
#  'imgs/test/bookstore_video1_13440.jpg',
#  'imgs/test/bookstore_video1_13470.jpg',
#  'imgs/test/bookstore_video1_13500.jpg',
#  'imgs/test/bookstore_video1_13530.jpg',
#  'imgs/test/bookstore_video1_13560.jpg',
#  'imgs/test/bookstore_video1_13590.jpg',
#  'imgs/test/bookstore_video1_13620.jpg',
#  'imgs/test/bookstore_video1_13650.jpg',
#  'imgs/test/bookstore_video1_13680.jpg',
#  'imgs/test/bookstore_video1_13710.jpg',
#  'imgs/test/bookstore_video1_13740.jpg',
#  'imgs/test/bookstore_video1_13770.jpg',
#  'imgs/test/bookstore_video1_13800.jpg',
#  'imgs/test/bookstore_video1_13830.jpg',
#  'imgs/test/bookstore_video1_13860.jpg',
#  'imgs/test/bookstore_video1_13890.jpg',
#  'imgs/test/bookstore_video1_13920.jpg',
#  'imgs/test/bookstore_video1_13950.jpg',
#  'imgs/test/bookstore_video1_13980.jpg',
#  'imgs/test/bookstore_video1_14010.jpg',
#  'imgs/test/bookstore_video1_14040.jpg',
#  'imgs/test/bookstore_video1_14070.jpg',
#  'imgs/test/bookstore_video1_14100.jpg',
#  'imgs/test/bookstore_video1_14130.jpg',
#  'imgs/test/bookstore_video1_14160.jpg',
#  'imgs/test/bookstore_video1_14190.jpg',
#  'imgs/test/bookstore_video1_14220.jpg',
#  'imgs/test/bookstore_video1_14250.jpg',
#  'imgs/test/bookstore_video1_14280.jpg',
#  'imgs/test/bookstore_video1_14310.jpg',
#  'imgs/test/bookstore_video1_14340.jpg',
#  'imgs/test/bookstore_video1_14370.jpg',
#  'imgs/test/bookstore_video1_14400.jpg',
#  'imgs/test/bookstore_video1_14430.jpg',
#  'imgs/test/bookstore_video1_14460.jpg',
#  'imgs/test/bookstore_video1_14490.jpg',
#  'imgs/test/bookstore_video1_14520.jpg',
#  'imgs/test/bookstore_video1_14550.jpg',
#  'imgs/test/bookstore_video1_8010.jpg',
#  'imgs/test/bookstore_video1_8040.jpg',
#  'imgs/test/bookstore_video1_8070.jpg',
#  'imgs/test/bookstore_video1_8100.jpg',
#  'imgs/test/bookstore_video1_8130.jpg',
#  'imgs/test/bookstore_video1_8160.jpg',
#  'imgs/test/bookstore_video1_8190.jpg',
#  'imgs/test/bookstore_video1_8220.jpg',
#  'imgs/test/bookstore_video1_8250.jpg',
#  'imgs/test/bookstore_video1_8280.jpg',
#  'imgs/test/bookstore_video1_8310.jpg',
#  'imgs/test/bookstore_video1_8340.jpg',
#  'imgs/test/bookstore_video1_8370.jpg',
#  'imgs/test/bookstore_video1_8400.jpg',
#  'imgs/test/bookstore_video1_8430.jpg',
#  'imgs/test/bookstore_video1_8460.jpg',
#  'imgs/test/bookstore_video1_8490.jpg',
#  'imgs/test/bookstore_video1_8520.jpg',
#  'imgs/test/bookstore_video1_8550.jpg',
#  'imgs/test/bookstore_video1_8580.jpg',
#  'imgs/test/bookstore_video1_8610.jpg',
#  'imgs/test/bookstore_video1_8640.jpg',
#  'imgs/test/bookstore_video1_8670.jpg',
#  'imgs/test/bookstore_video1_8700.jpg',
#  'imgs/test/bookstore_video1_8730.jpg',
#  'imgs/test/bookstore_video1_8760.jpg',
#  'imgs/test/bookstore_video1_8790.jpg',
#  'imgs/test/bookstore_video1_8820.jpg',
#  'imgs/test/bookstore_video1_8850.jpg',
#  'imgs/test/bookstore_video1_8880.jpg',
#  'imgs/test/bookstore_video1_8910.jpg',
#  'imgs/test/bookstore_video1_8940.jpg',
#  'imgs/test/bookstore_video1_8970.jpg',
#  'imgs/test/bookstore_video1_9000.jpg',
#  'imgs/test/bookstore_video1_9030.jpg',
#  'imgs/test/bookstore_video1_9060.jpg',
#  'imgs/test/bookstore_video1_9090.jpg',
#  'imgs/test/bookstore_video1_9120.jpg',
#  'imgs/test/bookstore_video1_9150.jpg',
#  'imgs/test/bookstore_video1_9180.jpg',
#  'imgs/test/bookstore_video1_9210.jpg',
#  'imgs/test/bookstore_video1_9240.jpg',
#  'imgs/test/bookstore_video1_9270.jpg',
#  'imgs/test/bookstore_video1_9300.jpg',
#  'imgs/test/bookstore_video1_9330.jpg',
#  'imgs/test/bookstore_video1_9360.jpg',
#  'imgs/test/bookstore_video1_9390.jpg',
#  'imgs/test/bookstore_video1_9420.jpg',
#  'imgs/test/bookstore_video1_9450.jpg',
#  'imgs/test/bookstore_video1_9480.jpg',
#  'imgs/test/bookstore_video1_9510.jpg',
#  'imgs/test/bookstore_video1_9540.jpg',
#  'imgs/test/bookstore_video1_9570.jpg',
#  'imgs/test/bookstore_video1_9600.jpg',
#  'imgs/test/bookstore_video1_9630.jpg',
#  'imgs/test/bookstore_video1_9660.jpg',
#  'imgs/test/bookstore_video1_9690.jpg',
#  'imgs/test/bookstore_video1_9720.jpg',
#  'imgs/test/bookstore_video1_9750.jpg',
#  'imgs/test/bookstore_video1_9780.jpg',
#  'imgs/test/bookstore_video1_9810.jpg',
#  'imgs/test/bookstore_video1_9840.jpg',
#  'imgs/test/bookstore_video1_9870.jpg',
#  'imgs/test/bookstore_video1_9900.jpg',
#  'imgs/test/bookstore_video1_9930.jpg',
#  'imgs/test/bookstore_video1_9960.jpg',
#  'imgs/test/bookstore_video1_9990.jpg',
#  'imgs/test/coupa_video3_10020.jpg',
#  'imgs/test/coupa_video3_10050.jpg',
#  'imgs/test/coupa_video3_10080.jpg',
#  'imgs/test/coupa_video3_10110.jpg',
#  'imgs/test/coupa_video3_10140.jpg',
#  'imgs/test/coupa_video3_10170.jpg',
#  'imgs/test/coupa_video3_10200.jpg',
#  'imgs/test/coupa_video3_10230.jpg',
#  'imgs/test/coupa_video3_10260.jpg',
#  'imgs/test/coupa_video3_10290.jpg',
#  'imgs/test/coupa_video3_10320.jpg',
#  'imgs/test/coupa_video3_10350.jpg',
#  'imgs/test/coupa_video3_10380.jpg',
#  'imgs/test/coupa_video3_10410.jpg',
#  'imgs/test/coupa_video3_10440.jpg',
#  'imgs/test/coupa_video3_10470.jpg',
#  'imgs/test/coupa_video3_10500.jpg',
#  'imgs/test/coupa_video3_10530.jpg',
#  'imgs/test/coupa_video3_10560.jpg',
#  'imgs/test/coupa_video3_10590.jpg',
#  'imgs/test/coupa_video3_10620.jpg',
#  'imgs/test/coupa_video3_10650.jpg',
#  'imgs/test/coupa_video3_10680.jpg',
#  'imgs/test/coupa_video3_10710.jpg',
#  'imgs/test/coupa_video3_10740.jpg',
#  'imgs/test/coupa_video3_10770.jpg',
#  'imgs/test/coupa_video3_10800.jpg',
#  'imgs/test/coupa_video3_10830.jpg',
#  'imgs/test/coupa_video3_10860.jpg',
#  'imgs/test/coupa_video3_10890.jpg',
#  'imgs/test/coupa_video3_10920.jpg',
#  'imgs/test/coupa_video3_10950.jpg',
#  'imgs/test/coupa_video3_10980.jpg',
#  'imgs/test/coupa_video3_11010.jpg',
#  'imgs/test/coupa_video3_11040.jpg',
#  'imgs/test/coupa_video3_11070.jpg',
#  'imgs/test/coupa_video3_11100.jpg',
#  'imgs/test/coupa_video3_11130.jpg',
#  'imgs/test/coupa_video3_11160.jpg',
#  'imgs/test/coupa_video3_11190.jpg',
#  'imgs/test/coupa_video3_11220.jpg',
#  'imgs/test/coupa_video3_11250.jpg',
#  'imgs/test/coupa_video3_11280.jpg',
#  'imgs/test/coupa_video3_11310.jpg',
#  'imgs/test/coupa_video3_11340.jpg',
#  'imgs/test/coupa_video3_11370.jpg',
#  'imgs/test/coupa_video3_11400.jpg',
#  'imgs/test/coupa_video3_11430.jpg',
#  'imgs/test/coupa_video3_11460.jpg',
#  'imgs/test/coupa_video3_11490.jpg',
#  'imgs/test/coupa_video3_11520.jpg',
#  'imgs/test/coupa_video3_11550.jpg',
#  'imgs/test/coupa_video3_11580.jpg',
#  'imgs/test/coupa_video3_11610.jpg',
#  'imgs/test/coupa_video3_11640.jpg',
#  'imgs/test/coupa_video3_11670.jpg',
#  'imgs/test/coupa_video3_11700.jpg',
#  'imgs/test/coupa_video3_11730.jpg',
#  'imgs/test/coupa_video3_11760.jpg',
#  'imgs/test/coupa_video3_11790.jpg',
#  'imgs/test/coupa_video3_11820.jpg',
#  'imgs/test/coupa_video3_11850.jpg',
#  'imgs/test/coupa_video3_11880.jpg',
#  'imgs/test/coupa_video3_11910.jpg',
#  'imgs/test/coupa_video3_11940.jpg',
#  'imgs/test/coupa_video3_6600.jpg',
#  'imgs/test/coupa_video3_6630.jpg',
#  'imgs/test/coupa_video3_6660.jpg',
#  'imgs/test/coupa_video3_6690.jpg',
#  'imgs/test/coupa_video3_6720.jpg',
#  'imgs/test/coupa_video3_6750.jpg',
#  'imgs/test/coupa_video3_6780.jpg',
#  'imgs/test/coupa_video3_6810.jpg',
#  'imgs/test/coupa_video3_6840.jpg',
#  'imgs/test/coupa_video3_6870.jpg',
#  'imgs/test/coupa_video3_6900.jpg',
#  'imgs/test/coupa_video3_6930.jpg',
#  'imgs/test/coupa_video3_6960.jpg',
#  'imgs/test/coupa_video3_6990.jpg',
#  'imgs/test/coupa_video3_7020.jpg',
#  'imgs/test/coupa_video3_7050.jpg',
#  'imgs/test/coupa_video3_7080.jpg',
#  'imgs/test/coupa_video3_7110.jpg',
#  'imgs/test/coupa_video3_7140.jpg',
#  'imgs/test/coupa_video3_7170.jpg',
#  'imgs/test/coupa_video3_7200.jpg',
#  'imgs/test/coupa_video3_7230.jpg',
#  'imgs/test/coupa_video3_7260.jpg',
#  'imgs/test/coupa_video3_7290.jpg',
#  'imgs/test/coupa_video3_7320.jpg',
#  'imgs/test/coupa_video3_7350.jpg',
#  'imgs/test/coupa_video3_7380.jpg',
#  'imgs/test/coupa_video3_7410.jpg',
#  'imgs/test/coupa_video3_7440.jpg',
#  'imgs/test/coupa_video3_7470.jpg',
#  'imgs/test/coupa_video3_7500.jpg',
#  'imgs/test/coupa_video3_7530.jpg',
#  'imgs/test/coupa_video3_7560.jpg',
#  'imgs/test/coupa_video3_7590.jpg',
#  'imgs/test/coupa_video3_7620.jpg',
#  'imgs/test/coupa_video3_7650.jpg',
#  'imgs/test/coupa_video3_7680.jpg',
#  'imgs/test/coupa_video3_7710.jpg',
#  'imgs/test/coupa_video3_7740.jpg',
#  'imgs/test/coupa_video3_7770.jpg',
#  'imgs/test/coupa_video3_7800.jpg',
#  'imgs/test/coupa_video3_7830.jpg',
#  'imgs/test/coupa_video3_7860.jpg',
#  'imgs/test/coupa_video3_7890.jpg',
#  'imgs/test/coupa_video3_7920.jpg',
#  'imgs/test/coupa_video3_7950.jpg',
#  'imgs/test/coupa_video3_7980.jpg',
#  'imgs/test/coupa_video3_8010.jpg',
#  'imgs/test/coupa_video3_8040.jpg',
#  'imgs/test/coupa_video3_8070.jpg',
#  'imgs/test/coupa_video3_8100.jpg',
#  'imgs/test/coupa_video3_8130.jpg',
#  'imgs/test/coupa_video3_8160.jpg',
#  'imgs/test/coupa_video3_8190.jpg',
#  'imgs/test/coupa_video3_8220.jpg',
#  'imgs/test/coupa_video3_8250.jpg',
#  'imgs/test/coupa_video3_8280.jpg',
#  'imgs/test/coupa_video3_8310.jpg',
#  'imgs/test/coupa_video3_8340.jpg',
#  'imgs/test/coupa_video3_8370.jpg',
#  'imgs/test/coupa_video3_8400.jpg',
#  'imgs/test/coupa_video3_8430.jpg',
#  'imgs/test/coupa_video3_8460.jpg',
#  'imgs/test/coupa_video3_8490.jpg',
#  'imgs/test/coupa_video3_8520.jpg',
#  'imgs/test/coupa_video3_8550.jpg',
#  'imgs/test/coupa_video3_8580.jpg',
#  'imgs/test/coupa_video3_8610.jpg',
#  'imgs/test/coupa_video3_8640.jpg',
#  'imgs/test/coupa_video3_8670.jpg',
#  'imgs/test/coupa_video3_8700.jpg',
#  'imgs/test/coupa_video3_8730.jpg',
#  'imgs/test/coupa_video3_8760.jpg',
#  'imgs/test/coupa_video3_8790.jpg',
#  'imgs/test/coupa_video3_8820.jpg',
#  'imgs/test/coupa_video3_8850.jpg',
#  'imgs/test/coupa_video3_8880.jpg',
#  'imgs/test/coupa_video3_8910.jpg',
#  'imgs/test/coupa_video3_8940.jpg',
#  'imgs/test/coupa_video3_8970.jpg',
#  'imgs/test/coupa_video3_9000.jpg',
#  'imgs/test/coupa_video3_9030.jpg',
#  'imgs/test/coupa_video3_9060.jpg',
#  'imgs/test/coupa_video3_9090.jpg',
#  'imgs/test/coupa_video3_9120.jpg',
#  'imgs/test/coupa_video3_9150.jpg',
#  'imgs/test/coupa_video3_9180.jpg',
#  'imgs/test/coupa_video3_9210.jpg',
#  'imgs/test/coupa_video3_9240.jpg',
#  'imgs/test/coupa_video3_9270.jpg',
#  'imgs/test/coupa_video3_9300.jpg',
#  'imgs/test/coupa_video3_9330.jpg',
#  'imgs/test/coupa_video3_9360.jpg',
#  'imgs/test/coupa_video3_9390.jpg',
#  'imgs/test/coupa_video3_9420.jpg',
#  'imgs/test/coupa_video3_9450.jpg',
#  'imgs/test/coupa_video3_9480.jpg',
#  'imgs/test/coupa_video3_9510.jpg',
#  'imgs/test/coupa_video3_9540.jpg',
#  'imgs/test/coupa_video3_9570.jpg',
#  'imgs/test/coupa_video3_9600.jpg',
#  'imgs/test/coupa_video3_9630.jpg',
#  'imgs/test/coupa_video3_9660.jpg',
#  'imgs/test/coupa_video3_9690.jpg',
#  'imgs/test/coupa_video3_9720.jpg',
#  'imgs/test/coupa_video3_9750.jpg',
#  'imgs/test/coupa_video3_9780.jpg',
#  'imgs/test/coupa_video3_9810.jpg',
#  'imgs/test/coupa_video3_9840.jpg',
#  'imgs/test/coupa_video3_9870.jpg',
#  'imgs/test/coupa_video3_9900.jpg',
#  'imgs/test/coupa_video3_9930.jpg',
#  'imgs/test/coupa_video3_9960.jpg',
#  'imgs/test/coupa_video3_9990.jpg',
#  'imgs/test/deathCircle_video4_270.jpg',
#  'imgs/test/deathCircle_video4_300.jpg',
#  'imgs/test/deathCircle_video4_330.jpg',
#  'imgs/test/deathCircle_video4_360.jpg',
#  'imgs/test/deathCircle_video4_390.jpg',
#  'imgs/test/deathCircle_video4_420.jpg',
#  'imgs/test/deathCircle_video4_450.jpg',
#  'imgs/test/gates_video5_1170.jpg',
#  'imgs/test/gates_video5_1200.jpg',
#  'imgs/test/gates_video5_1230.jpg',
#  'imgs/test/gates_video5_1260.jpg',
#  'imgs/test/gates_video5_1290.jpg',
#  'imgs/test/gates_video5_1320.jpg',
#  'imgs/test/gates_video5_1350.jpg',
#  'imgs/test/gates_video5_1380.jpg',
#  'imgs/test/gates_video5_1410.jpg',
#  'imgs/test/gates_video5_1440.jpg',
#  'imgs/test/gates_video5_1470.jpg',
#  'imgs/test/gates_video5_1500.jpg',
#  'imgs/test/gates_video5_1530.jpg',
#  'imgs/test/gates_video5_1560.jpg',
#  'imgs/test/gates_video5_1590.jpg',
#  'imgs/test/gates_video5_1620.jpg',
#  'imgs/test/gates_video5_1650.jpg',
#  'imgs/test/gates_video5_1680.jpg',
#  'imgs/test/gates_video5_1710.jpg',
#  'imgs/test/gates_video5_1740.jpg',
#  'imgs/test/gates_video5_1770.jpg',
#  'imgs/test/gates_video5_1800.jpg',
#  'imgs/test/gates_video5_1830.jpg',
#  'imgs/test/gates_video5_1860.jpg',
#  'imgs/test/gates_video5_1890.jpg',
#  'imgs/test/gates_video5_1920.jpg',
#  'imgs/test/gates_video5_1950.jpg',
#  'imgs/test/gates_video5_1980.jpg',
#  'imgs/test/gates_video5_2010.jpg',
#  'imgs/test/gates_video5_2040.jpg',
#  'imgs/test/gates_video5_2070.jpg',
#  'imgs/test/hyang_video7_330.jpg',
#  'imgs/test/hyang_video7_360.jpg',
#  'imgs/test/hyang_video7_390.jpg',
#  'imgs/test/hyang_video7_420.jpg',
#  'imgs/test/hyang_video7_450.jpg',
#  'imgs/test/hyang_video7_480.jpg',
#  'imgs/test/hyang_video7_510.jpg',
#  'imgs/test/hyang_video7_540.jpg',
#  'imgs/test/hyang_video7_570.jpg',
#  'imgs/test/little_video1_10020.jpg',
#  'imgs/test/little_video1_10050.jpg',
#  'imgs/test/little_video1_10080.jpg',
#  'imgs/test/little_video1_10110.jpg',
#  'imgs/test/little_video1_10140.jpg',
#  'imgs/test/little_video1_10170.jpg',
#  'imgs/test/little_video1_10200.jpg',
#  'imgs/test/little_video1_10230.jpg',
#  'imgs/test/little_video1_10260.jpg',
#  'imgs/test/little_video1_10290.jpg',
#  'imgs/test/little_video1_10320.jpg',
#  'imgs/test/little_video1_10350.jpg',
#  'imgs/test/little_video1_10380.jpg',
#  'imgs/test/little_video1_10410.jpg',
#  'imgs/test/little_video1_10440.jpg',
#  'imgs/test/little_video1_10470.jpg',
#  'imgs/test/little_video1_10500.jpg',
#  'imgs/test/little_video1_10530.jpg',
#  'imgs/test/little_video1_10560.jpg',
#  'imgs/test/little_video1_10590.jpg',
#  'imgs/test/little_video1_10620.jpg',
#  'imgs/test/little_video1_10650.jpg',
#  'imgs/test/little_video1_10680.jpg',
#  'imgs/test/little_video1_10710.jpg',
#  'imgs/test/little_video1_10740.jpg',
#  'imgs/test/little_video1_10770.jpg',
#  'imgs/test/little_video1_10800.jpg',
#  'imgs/test/little_video1_10830.jpg',
#  'imgs/test/little_video1_10860.jpg',
#  'imgs/test/little_video1_10890.jpg',
#  'imgs/test/little_video1_10920.jpg',
#  'imgs/test/little_video1_10950.jpg',
#  'imgs/test/little_video1_10980.jpg',
#  'imgs/test/little_video1_11010.jpg',
#  'imgs/test/little_video1_11040.jpg',
#  'imgs/test/little_video1_11070.jpg',
#  'imgs/test/little_video1_11100.jpg',
#  'imgs/test/little_video1_11130.jpg',
#  'imgs/test/little_video1_11160.jpg',
#  'imgs/test/little_video1_11190.jpg',
#  'imgs/test/little_video1_11220.jpg',
#  'imgs/test/little_video1_11250.jpg',
#  'imgs/test/little_video1_11280.jpg',
#  'imgs/test/little_video1_11310.jpg',
#  'imgs/test/little_video1_11340.jpg',
#  'imgs/test/little_video1_11370.jpg',
#  'imgs/test/little_video1_11400.jpg',
#  'imgs/test/little_video1_11430.jpg',
#  'imgs/test/little_video1_11460.jpg',
#  'imgs/test/little_video1_11490.jpg',
#  'imgs/test/little_video1_11520.jpg',
#  'imgs/test/little_video1_11550.jpg',
#  'imgs/test/little_video1_11580.jpg',
#  'imgs/test/little_video1_11610.jpg',
#  'imgs/test/little_video1_11640.jpg',
#  'imgs/test/little_video1_11670.jpg',
#  'imgs/test/little_video1_11700.jpg',
#  'imgs/test/little_video1_11730.jpg',
#  'imgs/test/little_video1_11760.jpg',
#  'imgs/test/little_video1_11790.jpg',
#  'imgs/test/little_video1_11820.jpg',
#  'imgs/test/little_video1_11850.jpg',
#  'imgs/test/little_video1_11880.jpg',
#  'imgs/test/little_video1_11910.jpg',
#  'imgs/test/little_video1_11940.jpg',
#  'imgs/test/little_video1_11970.jpg',
#  'imgs/test/little_video1_12000.jpg',
#  'imgs/test/little_video1_12030.jpg',
#  'imgs/test/little_video1_12060.jpg',
#  'imgs/test/little_video1_12090.jpg',
#  'imgs/test/little_video1_12120.jpg',
#  'imgs/test/little_video1_12150.jpg',
#  'imgs/test/little_video1_12180.jpg',
#  'imgs/test/little_video1_12210.jpg',
#  'imgs/test/little_video1_12240.jpg',
#  'imgs/test/little_video1_12270.jpg',
#  'imgs/test/little_video1_12300.jpg',
#  'imgs/test/little_video1_12330.jpg',
#  'imgs/test/little_video1_12360.jpg',
#  'imgs/test/little_video1_12390.jpg',
#  'imgs/test/little_video1_12420.jpg',
#  'imgs/test/little_video1_12450.jpg',
#  'imgs/test/little_video1_12480.jpg',
#  'imgs/test/little_video1_12510.jpg',
#  'imgs/test/little_video1_12540.jpg',
#  'imgs/test/little_video1_12570.jpg',
#  'imgs/test/little_video1_12600.jpg',
#  'imgs/test/little_video1_12630.jpg',
#  'imgs/test/little_video1_12660.jpg',
#  'imgs/test/little_video1_12690.jpg',
#  'imgs/test/little_video1_12720.jpg',
#  'imgs/test/little_video1_12750.jpg',
#  'imgs/test/little_video1_12780.jpg',
#  'imgs/test/little_video1_12810.jpg',
#  'imgs/test/little_video1_12840.jpg',
#  'imgs/test/little_video1_12870.jpg',
#  'imgs/test/little_video1_12900.jpg',
#  'imgs/test/little_video1_12930.jpg',
#  'imgs/test/little_video1_12960.jpg',
#  'imgs/test/little_video1_12990.jpg',
#  'imgs/test/little_video1_13020.jpg',
#  'imgs/test/little_video1_13050.jpg',
#  'imgs/test/little_video1_13080.jpg',
#  'imgs/test/little_video1_13110.jpg',
#  'imgs/test/little_video1_13140.jpg',
#  'imgs/test/little_video1_13170.jpg',
#  'imgs/test/little_video1_13200.jpg',
#  'imgs/test/little_video1_13230.jpg',
#  'imgs/test/little_video1_13260.jpg',
#  'imgs/test/little_video1_13290.jpg',
#  'imgs/test/little_video1_13320.jpg',
#  'imgs/test/little_video1_13350.jpg',
#  'imgs/test/little_video1_13380.jpg',
#  'imgs/test/little_video1_13410.jpg',
#  'imgs/test/little_video1_13440.jpg',
#  'imgs/test/little_video1_13470.jpg',
#  'imgs/test/little_video1_13500.jpg',
#  'imgs/test/little_video1_13530.jpg',
#  'imgs/test/little_video1_13560.jpg',
#  'imgs/test/little_video1_13590.jpg',
#  'imgs/test/little_video1_13620.jpg',
#  'imgs/test/little_video1_13650.jpg',
#  'imgs/test/little_video1_13680.jpg',
#  'imgs/test/little_video1_13710.jpg',
#  'imgs/test/little_video1_13740.jpg',
#  'imgs/test/little_video1_13770.jpg',
#  'imgs/test/little_video1_13800.jpg',
#  'imgs/test/little_video1_13830.jpg',
#  'imgs/test/little_video1_13860.jpg',
#  'imgs/test/little_video1_13890.jpg',
#  'imgs/test/little_video1_13920.jpg',
#  'imgs/test/little_video1_13950.jpg',
#  'imgs/test/little_video1_13980.jpg',
#  'imgs/test/little_video1_14010.jpg',
#  'imgs/test/little_video1_14040.jpg',
#  'imgs/test/little_video1_7740.jpg',
#  'imgs/test/little_video1_7770.jpg',
#  'imgs/test/little_video1_7800.jpg',
#  'imgs/test/little_video1_7830.jpg',
#  'imgs/test/little_video1_7860.jpg',
#  'imgs/test/little_video1_7890.jpg',
#  'imgs/test/little_video1_7920.jpg',
#  'imgs/test/little_video1_7950.jpg',
#  'imgs/test/little_video1_7980.jpg',
#  'imgs/test/little_video1_8010.jpg',
#  'imgs/test/little_video1_8040.jpg',
#  'imgs/test/little_video1_8070.jpg',
#  'imgs/test/little_video1_8100.jpg',
#  'imgs/test/little_video1_8130.jpg',
#  'imgs/test/little_video1_8160.jpg',
#  'imgs/test/little_video1_8190.jpg',
#  'imgs/test/little_video1_8220.jpg',
#  'imgs/test/little_video1_8250.jpg',
#  'imgs/test/little_video1_8280.jpg',
#  'imgs/test/little_video1_8310.jpg',
#  'imgs/test/little_video1_8340.jpg',
#  'imgs/test/little_video1_8370.jpg',
#  'imgs/test/little_video1_8400.jpg',
#  'imgs/test/little_video1_8430.jpg',
#  'imgs/test/little_video1_8460.jpg',
#  'imgs/test/little_video1_8490.jpg',
#  'imgs/test/little_video1_8520.jpg',
#  'imgs/test/little_video1_8550.jpg',
#  'imgs/test/little_video1_8580.jpg',
#  'imgs/test/little_video1_8610.jpg',
#  'imgs/test/little_video1_8640.jpg',
#  'imgs/test/little_video1_8670.jpg',
#  'imgs/test/little_video1_8700.jpg',
#  'imgs/test/little_video1_8730.jpg',
#  'imgs/test/little_video1_8760.jpg',
#  'imgs/test/little_video1_8790.jpg',
#  'imgs/test/little_video1_8820.jpg',
#  'imgs/test/little_video1_8850.jpg',
#  'imgs/test/little_video1_8880.jpg',
#  'imgs/test/little_video1_8910.jpg',
#  'imgs/test/little_video1_8940.jpg',
#  'imgs/test/little_video1_8970.jpg',
#  'imgs/test/little_video1_9000.jpg',
#  'imgs/test/little_video1_9030.jpg',
#  'imgs/test/little_video1_9060.jpg',
#  'imgs/test/little_video1_9090.jpg',
#  'imgs/test/little_video1_9120.jpg',
#  'imgs/test/little_video1_9150.jpg',
#  'imgs/test/little_video1_9180.jpg',
#  'imgs/test/little_video1_9210.jpg',
#  'imgs/test/little_video1_9240.jpg',
#  'imgs/test/little_video1_9270.jpg',
#  'imgs/test/little_video1_9300.jpg',
#  'imgs/test/little_video1_9330.jpg',
#  'imgs/test/little_video1_9360.jpg',
#  'imgs/test/little_video1_9390.jpg',
#  'imgs/test/little_video1_9420.jpg',
#  'imgs/test/little_video1_9450.jpg',
#  'imgs/test/little_video1_9480.jpg',
#  'imgs/test/little_video1_9510.jpg',
#  'imgs/test/little_video1_9540.jpg',
#  'imgs/test/little_video1_9570.jpg',
#  'imgs/test/little_video1_9600.jpg',
#  'imgs/test/little_video1_9630.jpg',
#  'imgs/test/little_video1_9660.jpg',
#  'imgs/test/little_video1_9690.jpg',
#  'imgs/test/little_video1_9720.jpg',
#  'imgs/test/little_video1_9750.jpg',
#  'imgs/test/little_video1_9780.jpg',
#  'imgs/test/little_video1_9810.jpg',
#  'imgs/test/little_video1_9840.jpg',
#  'imgs/test/little_video1_9870.jpg',
#  'imgs/test/little_video1_9900.jpg',
#  'imgs/test/little_video1_9930.jpg',
#  'imgs/test/little_video1_9960.jpg',
#  'imgs/test/little_video1_9990.jpg',
#  'imgs/test/quad_video2_300.jpg',
#  'imgs/test/quad_video2_330.jpg',
#  'imgs/test/quad_video2_360.jpg',
#  'imgs/test/quad_video2_390.jpg',
#  'imgs/test/quad_video2_420.jpg',
#  'imgs/test/quad_video2_450.jpg',
#  'imgs/test/quad_video2_480.jpg']

# %%
score_threshold_retinanet = 0.8
acceptable_box_overlap = 0.3

# %%
def get_gt_annotations(filepath):
    gt_ann = []
    with open (os.path.join(cwd, annotations_file)) as csvfile:
        readCSV = csv.reader(csvfile, delimiter='\n')
        for row in readCSV:
            vals = row[0].split(',')
            this_filepath = vals[0]
            
            if this_filepath == filepath:
                record = []
                record.append(int(vals[1]))
                record.append(int(vals[2]))
                record.append(int(vals[3]))
                record.append(int(vals[4]))
                record.append(vals[5])
                
                gt_ann.append(record)
          
        if this_filepath == filepath:
            record = []
            record.append(int(vals[1]))
            record.append(int(vals[2]))
            record.append(int(vals[3]))
            record.append(int(vals[4]))
            record.append(vals[5])
              
            gt_ann.append(record)
    return gt_ann

# %%
def bb_intersection_over_union(boxA, boxB):
	# determine the (x, y)-coordinates of the intersection rectangle
	xA = max(int(boxA[0]), int(boxB[0]))
	yA = max(int(boxA[1]), int(boxB[1]))
	xB = min(int(boxA[2]), int(boxB[2]))
	yB = min(int(boxA[3]), int(boxB[3]))
 
	# compute the area of intersection rectangle
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
 
	# compute the area of both the prediction and ground-truth
	# rectangles
	boxAArea = (int(boxA[2]) - int(boxA[0]) + 1) * (int(boxA[3]) - int(boxA[1]) + 1)
	boxBArea = (int(boxB[2]) - int(boxB[0]) + 1) * (int(boxB[3]) - int(boxB[1]) + 1)
 
	# compute the intersection over union by taking the intersection
	# area and dividing it by the sum of prediction + ground-truth
	# areas - the interesection area
	iou = interArea / float(boxAArea + boxBArea - interArea)
 
	# return the intersection over union value
	return iou

# %%
def highest_iou(predicted_box, gt_ann):
    
    highest_iou = 0
    best_match = []
    for each_gt in gt_ann:
        this_iou = bb_intersection_over_union(predicted_box[:-1], each_gt[:-1])
#         print(" For this box is: ", this_iou)
        if this_iou > highest_iou:
            highest_iou = this_iou
            best_match = each_gt
            
    return highest_iou, best_match

# %%
def accuracy(gt_ann, predicted_ann):
    true_positive = []
    class_mismatch = []
    false_positive = []
    false_negative = []
    tp_classes = []
    cm_classes = []
    fp_classes = []
    fn_classes = []

    predicted_ann_copy = predicted_ann.copy()
    gt_ann_copy = gt_ann.copy()
    
    for each_pred in predicted_ann_copy:
        # 1. Calculate the highest_iou with any gt_box
        best_iou, best_gt_match = highest_iou(each_pred, gt_ann_copy)
#         print("Best IOU is: ", each_pred, best_gt_match, best_iou)
        
        ## If this box has a match
        if best_iou >= acceptable_box_overlap:
            ## if class label matches
            if best_gt_match[-1] == each_pred[-1]:
                ## This is a true positive
                true_positive.append(each_pred)
                ## remove this from predicted ann and gt
#                 print("Predicted Ann before:", predicted_ann)
                predicted_ann.remove(each_pred)
                tp_classes.append(each_pred[-1])
#                 print("Predicted Ann after:", predicted_ann)
                if best_gt_match in gt_ann:
                    gt_ann.remove(best_gt_match)
            elif best_gt_match[-1] != each_pred[-1]:
                ## this is a class mismatch
                class_mismatch.append(each_pred)
                cm_classes.append(each_pred[-1])
                ## remove this box
                predicted_ann.remove(each_pred)
                if best_gt_match in gt_ann:
                    gt_ann.remove(best_gt_match)
        
    ## If IOU is less than 0.5, leave as is

    ## Any predicted box is now false positive
    for remain_pred in predicted_ann:
        false_positive.append(remain_pred)
        fp_classes.append(remain_pred[-1])
        if len(gt_ann) != 0:
          gt_ann.pop(0)

    ## Any remaining gt box is false negative
    for remain_gt in gt_ann:
        if remain_gt[-1] in ['Biker','Bus', 'Car', 'Person']:
            false_negative.append(remain_gt)
            fn_classes.append(remain_gt[-1])

    return true_positive, class_mismatch, false_positive, false_negative, tp_classes, cm_classes, fp_classes, fn_classes

# %%
def run_detection_image(filepath):
    image = read_image_bgr(filepath)
    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

    # preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

    # process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

    # correct for image scale
    boxes /= scale
    
    gt_ann = get_gt_annotations(filepath)
    num_gt_ann = len(gt_ann)
    
    predicted_ann = []
    true_P_classes = []
    c_mis_classes = []
    false_P_classes = []
    false_N_classes = []

    # visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        if score < score_threshold_retinanet:
            break

        record = []
        record.append(int(box[0]))
        record.append(int(box[1]))
        record.append(int(box[2]))
        record.append(int(box[3]))
        record.append(labels_to_names[label])
        print("Record is: ", record)
        predicted_ann.append(record)
       
    ## Calculate boxes
    true_positive, class_mismatch, false_positive, false_negative, true_P_classes, c_mis_classes, false_P_classes, false_N_classes = accuracy(gt_ann, predicted_ann)
    print(len(true_positive), len(class_mismatch), len(false_positive), len(false_negative))
    
    return len(true_positive), len(class_mismatch), len(false_positive), len(false_negative), num_gt_ann, true_P_classes, c_mis_classes, false_P_classes, false_N_classes

# %%
total_true_positive = 0
total_class_mismatch = 0
total_false_positive = 0
total_false_negative = 0
total_gt = 0

# %%
num_tp, num_cm , num_fp, num_fn, num_gt = run_detection_image("imgs/test/bookstore_video1_10020.jpg")

# %%
tp_cl = []
cm_cl = []
fp_cl = []
fn_cl = []

tp_cl2 = []
cm_cl2 = []
fp_cl2 = []
fn_cl2 = []

for filepath in image_names:
    print(filepath)
    num_tp, num_cm , num_fp, num_fn, num_gt, tp_cl, cm_cl, fp_cl, fn_cl = run_detection_image(filepath)
    print("Ground Truth: ", num_gt)
    total_true_positive += num_tp
    total_class_mismatch += num_cm
    total_false_positive += num_fp
    total_false_negative += num_fn
    total_gt += num_gt
    tp_cl2.append(tp_cl)
    cm_cl2.append(cm_cl)
    fp_cl2.append(fp_cl)
    fn_cl2.append(fn_cl)
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
# Record is:  [707, 331, 742, 375, 'Person']
# Record is:  [773, 277, 806, 322, 'Person']
# Record is:  [944, 711, 974, 750, 'Person']
# Record is:  [229, 504, 261, 540, 'Person']
# Record is:  [184, 722, 211, 772, 'Person']
# Record is:  [219, 474, 243, 502, 'Person']
# Record is:  [85, 737, 110, 780, 'Person']
# Record is:  [587, 586, 629, 642, 'Biker']
# 10 0 0 1
# Ground Truth:  11
# imgs/test/bookstore_video1_9990.jpg
# processing time:  0.06113147735595703
# Record is:  [920, 694, 950, 731, 'Person']
# Record is:  [1376, 202, 1407, 244, 'Person']
# Record is:  [704, 331, 735, 379, 'Person']
# Record is:  [778, 285, 811, 332, 'Person']
# Record is:  [744, 269, 769, 309, 'Person']
# Record is:  [87, 766, 111, 806, 'Person']
# Record is:  [211, 721, 236, 771, 'Person']
# Record is:  [96, 719, 119, 761, 'Person']
# Record is:  [219, 474, 243, 503, 'Person']
# Record is:  [229, 504, 259, 540, 'Person']
# Record is:  [477, 568, 518, 620, 'Biker']
# 11 0 0 0
# Ground Truth:  11
# imgs/test/coupa_video3_10020.jpg
# processing time:  2.7269935607910156
# Record is:  [1434, 110, 1506, 160, 'Person']
# Record is:  [1333, 109, 1372, 144, 'Person']
# Record is:  [1358, 168, 1424, 240, 'Person']
# Record is:  [1286, 116, 1332, 150, 'Person']
# Record is:  [1287, 91, 1335, 115, 'Person']
# Record is:  [1327, 140, 1363, 175, 'Person']
# Record is:  [366, 912, 426, 963, 'Person']
# Record is:  [414, 361, 477, 416, 'Person']
# Record is:  [585, 354, 641, 407, 'Person']
# Record is:  [1280, 144, 1330, 185, 'Person']
# Record is:  [1292, 59, 1333, 88, 'Person']
# Record is:  [1448, 739, 1509, 776, 'Person']
# Record is:  [1405, 150, 1463, 199, 'Person']
# Record is:  [318, 947, 365, 998, 'Person']
# Record is:  [1415, 159, 1462, 187, 'Person']
# Record is:  [343, 944, 397, 991, 'Person']
# 16 0 0 1
# Ground Truth:  17
# imgs/test/coupa_video3_10050.jpg
# processing time:  0.07082557678222656
# Record is:  [1333, 108, 1372, 145, 'Person']
# Record is:  [1286, 116, 1333, 151, 'Person']
# Record is:  [1403, 155, 1465, 205, 'Person']
# Record is:  [1287, 91, 1336, 115, 'Person']
# Record is:  [1327, 140, 1363, 175, 'Person']
# Record is:  [401, 914, 483, 965, 'Person']
# Record is:  [1281, 147, 1330, 185, 'Person']
# Record is:  [1435, 112, 1508, 160, 'Person']
# Record is:  [1292, 59, 1333, 87, 'Person']
# Record is:  [415, 361, 477, 415, 'Person']
# Record is:  [584, 356, 641, 406, 'Person']
# Record is:  [1448, 740, 1509, 776, 'Person']
# Record is:  [1415, 159, 1462, 188, 'Person']
# Record is:  [336, 950, 382, 1001, 'Person']
# Record is:  [1373, 125, 1444, 189, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10080.jpg
# processing time:  0.07279849052429199
# Record is:  [1332, 108, 1372, 145, 'Person']
# Record is:  [1286, 117, 1333, 151, 'Person']
# Record is:  [441, 909, 519, 960, 'Person']
# Record is:  [1385, 81, 1444, 144, 'Person']
# Record is:  [1283, 151, 1332, 187, 'Person']
# Record is:  [1327, 141, 1363, 175, 'Person']
# Record is:  [584, 357, 642, 409, 'Person']
# Record is:  [1400, 150, 1465, 207, 'Person']
# Record is:  [1287, 90, 1335, 115, 'Person']
# Record is:  [1448, 740, 1508, 775, 'Person']
# Record is:  [414, 361, 477, 415, 'Person']
# Record is:  [1291, 59, 1333, 87, 'Person']
# Record is:  [351, 954, 396, 1004, 'Person']
# Record is:  [1435, 110, 1507, 158, 'Person']
# Record is:  [1416, 159, 1462, 188, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10110.jpg
# processing time:  0.07106924057006836
# Record is:  [1332, 108, 1375, 144, 'Person']
# Record is:  [1285, 154, 1335, 191, 'Person']
# Record is:  [1437, 111, 1506, 158, 'Person']
# Record is:  [1287, 91, 1336, 116, 'Person']
# Record is:  [1400, 152, 1468, 206, 'Person']
# Record is:  [1328, 140, 1363, 174, 'Person']
# Record is:  [1287, 118, 1334, 151, 'Person']
# Record is:  [1400, 39, 1454, 96, 'Person']
# Record is:  [375, 953, 419, 1005, 'Person']
# Record is:  [584, 355, 642, 409, 'Person']
# Record is:  [477, 906, 560, 956, 'Person']
# Record is:  [415, 361, 478, 416, 'Person']
# Record is:  [1416, 158, 1462, 187, 'Person']
# Record is:  [1448, 740, 1508, 775, 'Person']
# 14 0 0 1
# Ground Truth:  15
# imgs/test/coupa_video3_10140.jpg
# processing time:  0.0711066722869873
# Record is:  [1287, 118, 1333, 152, 'Person']
# Record is:  [1333, 108, 1375, 144, 'Person']
# Record is:  [1438, 111, 1503, 157, 'Person']
# Record is:  [500, 909, 579, 957, 'Person']
# Record is:  [1287, 157, 1336, 191, 'Person']
# Record is:  [1400, 154, 1467, 210, 'Person']
# Record is:  [1331, 141, 1364, 174, 'Person']
# Record is:  [584, 354, 642, 408, 'Person']
# Record is:  [414, 362, 477, 416, 'Person']
# Record is:  [1415, 0, 1465, 46, 'Person']
# Record is:  [1448, 740, 1508, 775, 'Person']
# Record is:  [1287, 91, 1335, 115, 'Person']
# Record is:  [395, 955, 443, 1004, 'Person']
# Record is:  [1415, 158, 1462, 188, 'Person']
# Record is:  [1292, 58, 1333, 87, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10170.jpg
# processing time:  0.07010412216186523
# Record is:  [516, 915, 595, 964, 'Person']
# Record is:  [1440, 111, 1503, 156, 'Person']
# Record is:  [1333, 108, 1376, 143, 'Person']
# Record is:  [1331, 142, 1365, 175, 'Person']
# Record is:  [1448, 739, 1508, 776, 'Person']
# Record is:  [1399, 156, 1468, 210, 'Person']
# Record is:  [1289, 158, 1338, 193, 'Person']
# Record is:  [1287, 91, 1335, 115, 'Person']
# Record is:  [1289, 117, 1335, 150, 'Person']
# Record is:  [585, 351, 647, 412, 'Person']
# Record is:  [415, 362, 477, 415, 'Person']
# Record is:  [1415, 159, 1463, 187, 'Person']
# Record is:  [428, 956, 473, 1004, 'Person']
# Record is:  [1291, 58, 1333, 88, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10200.jpg
# processing time:  0.07169175148010254
# Record is:  [537, 917, 613, 966, 'Person']
# Record is:  [1439, 110, 1503, 156, 'Person']
# Record is:  [1289, 118, 1336, 151, 'Person']
# Record is:  [1333, 108, 1378, 142, 'Person']
# Record is:  [415, 362, 477, 416, 'Person']
# Record is:  [1448, 739, 1509, 775, 'Person']
# Record is:  [1331, 143, 1366, 175, 'Person']
# Record is:  [1287, 90, 1336, 116, 'Person']
# Record is:  [584, 352, 646, 412, 'Person']
# Record is:  [1289, 161, 1339, 193, 'Person']
# Record is:  [1292, 58, 1333, 88, 'Person']
# Record is:  [90, 661, 182, 719, 'Biker']
# Record is:  [1416, 159, 1462, 187, 'Person']
# Record is:  [1401, 160, 1466, 210, 'Person']
# Record is:  [460, 955, 506, 1003, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10230.jpg
# processing time:  0.07152557373046875
# Record is:  [1440, 110, 1503, 153, 'Person']
# Record is:  [577, 914, 656, 965, 'Person']
# Record is:  [583, 351, 649, 413, 'Person']
# Record is:  [1331, 143, 1366, 175, 'Person']
# Record is:  [212, 653, 302, 706, 'Biker']
# Record is:  [1402, 159, 1465, 210, 'Person']
# Record is:  [1289, 119, 1337, 152, 'Person']
# Record is:  [1288, 91, 1336, 115, 'Person']
# Record is:  [1333, 109, 1377, 142, 'Person']
# Record is:  [415, 362, 477, 416, 'Person']
# Record is:  [1292, 163, 1342, 195, 'Person']
# Record is:  [1448, 740, 1509, 776, 'Person']
# Record is:  [1415, 159, 1462, 187, 'Person']
# Record is:  [492, 941, 537, 993, 'Person']
# Record is:  [1292, 59, 1333, 87, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10260.jpg
# processing time:  0.07058429718017578
# Record is:  [620, 913, 699, 963, 'Person']
# Record is:  [1333, 109, 1380, 142, 'Person']
# Record is:  [1441, 110, 1500, 153, 'Person']
# Record is:  [1289, 119, 1336, 151, 'Person']
# Record is:  [1333, 143, 1366, 174, 'Person']
# Record is:  [1287, 91, 1335, 115, 'Person']
# Record is:  [414, 362, 477, 415, 'Person']
# Record is:  [1402, 160, 1465, 209, 'Person']
# Record is:  [1448, 740, 1509, 776, 'Person']
# Record is:  [1292, 59, 1333, 87, 'Person']
# Record is:  [1292, 163, 1342, 194, 'Person']
# Record is:  [587, 351, 647, 413, 'Person']
# Record is:  [329, 645, 419, 700, 'Biker']
# Record is:  [524, 932, 569, 983, 'Person']
# Record is:  [1416, 159, 1463, 187, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10290.jpg
# processing time:  0.07170391082763672
# Record is:  [664, 910, 744, 959, 'Person']
# Record is:  [1443, 110, 1500, 152, 'Person']
# Record is:  [1289, 120, 1336, 152, 'Person']
# Record is:  [1333, 108, 1380, 143, 'Person']
# Record is:  [586, 349, 652, 415, 'Person']
# Record is:  [1292, 59, 1332, 87, 'Person']
# Record is:  [557, 920, 601, 971, 'Person']
# Record is:  [1292, 163, 1342, 195, 'Person']
# Record is:  [1333, 143, 1366, 174, 'Person']
# Record is:  [1404, 161, 1464, 209, 'Person']
# Record is:  [1287, 91, 1336, 116, 'Person']
# Record is:  [334, 13, 386, 70, 'Person']
# Record is:  [1448, 739, 1508, 776, 'Person']
# Record is:  [431, 629, 528, 685, 'Biker']
# Record is:  [414, 361, 477, 415, 'Person']
# Record is:  [1416, 159, 1463, 188, 'Person']
# 16 0 0 0
# Ground Truth:  16
# imgs/test/coupa_video3_10320.jpg
# processing time:  0.07046651840209961
# Record is:  [1333, 109, 1380, 142, 'Person']
# Record is:  [1290, 122, 1338, 154, 'Person']
# Record is:  [1287, 91, 1336, 115, 'Person']
# Record is:  [1441, 111, 1502, 151, 'Person']
# Record is:  [378, 29, 429, 85, 'Person']
# Record is:  [586, 350, 651, 415, 'Person']
# Record is:  [415, 361, 477, 415, 'Person']
# Record is:  [1333, 143, 1366, 174, 'Person']
# Record is:  [510, 597, 604, 650, 'Biker']
# Record is:  [1404, 162, 1465, 208, 'Person']
# Record is:  [1448, 740, 1509, 776, 'Person']
# Record is:  [1292, 163, 1342, 194, 'Person']
# Record is:  [1417, 159, 1463, 188, 'Person']
# Record is:  [595, 918, 639, 969, 'Person']
# Record is:  [1292, 60, 1333, 87, 'Person']
# Record is:  [702, 903, 782, 953, 'Person']
# 16 0 0 0
# Ground Truth:  16
# imgs/test/coupa_video3_10350.jpg
# processing time:  0.07030439376831055
# Record is:  [1332, 109, 1383, 141, 'Person']
# Record is:  [1291, 122, 1339, 154, 'Person']
# Record is:  [1446, 110, 1501, 151, 'Person']
# Record is:  [1292, 162, 1342, 194, 'Person']
# Record is:  [733, 896, 816, 947, 'Person']
# Record is:  [1287, 90, 1337, 115, 'Person']
# Record is:  [584, 349, 648, 414, 'Person']
# Record is:  [1292, 57, 1333, 88, 'Person']
# Record is:  [1333, 144, 1368, 175, 'Person']
# Record is:  [415, 361, 476, 415, 'Person']
# Record is:  [636, 918, 683, 967, 'Person']
# Record is:  [1447, 740, 1508, 776, 'Person']
# Record is:  [583, 569, 677, 622, 'Biker']
# Record is:  [1410, 159, 1463, 198, 'Person']
# Record is:  [59, 866, 104, 926, 'Biker']
# Record is:  [424, 46, 476, 104, 'Person']
# 16 0 0 1
# Ground Truth:  17
# imgs/test/coupa_video3_10380.jpg
# processing time:  0.07130098342895508
# Record is:  [1445, 110, 1498, 150, 'Person']
# Record is:  [769, 891, 846, 941, 'Person']
# Record is:  [1333, 109, 1382, 141, 'Person']
# Record is:  [471, 77, 522, 134, 'Person']
# Record is:  [1336, 145, 1368, 174, 'Person']
# Record is:  [586, 347, 653, 418, 'Person']
# Record is:  [1291, 121, 1338, 153, 'Person']
# Record is:  [1286, 90, 1335, 115, 'Person']
# Record is:  [1292, 162, 1342, 195, 'Person']
# Record is:  [1448, 739, 1508, 776, 'Person']
# Record is:  [674, 917, 720, 965, 'Person']
# Record is:  [414, 362, 477, 415, 'Person']
# Record is:  [1409, 159, 1462, 197, 'Person']
# Record is:  [1292, 59, 1332, 88, 'Person']
# Record is:  [205, 861, 248, 921, 'Biker']
# Record is:  [1405, 172, 1463, 210, 'Person']
# 16 0 0 1
# Ground Truth:  17
# imgs/test/coupa_video3_10410.jpg
# processing time:  0.07055377960205078
# Record is:  [1446, 111, 1498, 149, 'Person']
# Record is:  [588, 347, 653, 418, 'Person']
# Record is:  [1336, 144, 1369, 174, 'Person']
# Record is:  [1333, 109, 1383, 141, 'Person']
# Record is:  [1287, 91, 1336, 115, 'Person']
# Record is:  [798, 892, 880, 941, 'Person']
# Record is:  [1291, 122, 1338, 153, 'Person']
# Record is:  [1291, 162, 1342, 194, 'Person']
# Record is:  [1447, 740, 1508, 776, 'Person']
# Record is:  [715, 916, 758, 967, 'Person']
# Record is:  [415, 361, 477, 415, 'Person']
# Record is:  [1416, 159, 1463, 187, 'Person']
# Record is:  [517, 109, 569, 168, 'Person']
# Record is:  [351, 859, 396, 917, 'Biker']
# Record is:  [1406, 174, 1464, 212, 'Person']
# Record is:  [662, 406, 745, 461, 'Biker']
# Record is:  [1292, 59, 1333, 87, 'Person']
# 17 0 0 0
# Ground Truth:  17
# imgs/test/coupa_video3_10440.jpg
# processing time:  0.07095980644226074
# Record is:  [1448, 110, 1498, 148, 'Person']
# Record is:  [1287, 90, 1335, 115, 'Person']
# Record is:  [555, 142, 607, 202, 'Person']
# Record is:  [1415, 159, 1462, 188, 'Person']
# Record is:  [1332, 109, 1385, 141, 'Person']
# Record is:  [588, 345, 657, 420, 'Person']
# Record is:  [1336, 145, 1369, 175, 'Person']
# Record is:  [1291, 162, 1343, 195, 'Person']
# Record is:  [414, 362, 478, 416, 'Person']
# Record is:  [650, 321, 741, 375, 'Biker']
# Record is:  [1291, 58, 1333, 88, 'Person']
# Record is:  [1447, 739, 1507, 776, 'Person']
# Record is:  [1291, 121, 1338, 154, 'Person']
# Record is:  [749, 917, 794, 966, 'Person']
# Record is:  [1404, 175, 1463, 213, 'Person']
# Record is:  [496, 852, 541, 913, 'Biker']
# Record is:  [823, 899, 903, 949, 'Person']
# 17 0 0 0
# Ground Truth:  17
# imgs/test/coupa_video3_10470.jpg
# processing time:  0.07149362564086914
# Record is:  [1448, 110, 1498, 148, 'Person']
# Record is:  [587, 345, 656, 421, 'Person']
# Record is:  [849, 905, 928, 955, 'Person']
# Record is:  [1287, 90, 1335, 116, 'Person']
# Record is:  [415, 362, 476, 415, 'Person']
# Record is:  [1415, 158, 1463, 188, 'Person']
# Record is:  [1333, 109, 1386, 141, 'Person']
# Record is:  [1291, 121, 1339, 154, 'Person']
# Record is:  [1448, 740, 1509, 775, 'Person']
# Record is:  [1291, 59, 1332, 88, 'Person']
# Record is:  [1291, 163, 1343, 195, 'Person']
# Record is:  [784, 916, 830, 966, 'Person']
# Record is:  [1335, 144, 1369, 174, 'Person']
# Record is:  [587, 175, 639, 231, 'Person']
# Record is:  [626, 841, 671, 900, 'Biker']
# Record is:  [1405, 176, 1463, 213, 'Person']
# Record is:  [638, 233, 728, 285, 'Biker']
# 17 0 0 0
# Ground Truth:  17
# imgs/test/coupa_video3_10500.jpg
# processing time:  0.07107710838317871
# Record is:  [1451, 111, 1498, 148, 'Person']
# Record is:  [589, 345, 661, 418, 'Person']
# Record is:  [1287, 90, 1336, 116, 'Person']
# Record is:  [877, 914, 956, 966, 'Person']
# Record is:  [1292, 122, 1338, 154, 'Person']
# Record is:  [1335, 110, 1387, 141, 'Person']
# Record is:  [1415, 158, 1462, 188, 'Person']
# Record is:  [1338, 147, 1372, 175, 'Person']
# Record is:  [1291, 162, 1341, 194, 'Person']
# Record is:  [1291, 58, 1332, 88, 'Person']
# Record is:  [1449, 739, 1509, 776, 'Person']
# Record is:  [414, 362, 477, 416, 'Person']
# Record is:  [1405, 177, 1463, 213, 'Person']
# Record is:  [621, 145, 712, 200, 'Biker']
# Record is:  [824, 918, 868, 968, 'Person']
# Record is:  [757, 832, 799, 892, 'Biker']
# Record is:  [624, 209, 677, 259, 'Person']
# 17 0 0 0
# Ground Truth:  17
# imgs/test/coupa_video3_10530.jpg
# processing time:  0.07084774971008301
# Record is:  [583, 343, 662, 418, 'Person']
# Record is:  [1449, 111, 1498, 148, 'Person']
# Record is:  [1333, 109, 1386, 141, 'Person']
# Record is:  [901, 914, 971, 969, 'Person']
# Record is:  [525, 77, 625, 150, 'Biker']
# Record is:  [1289, 119, 1339, 152, 'Person']
# Record is:  [836, 916, 901, 981, 'Person']
# Record is:  [1336, 145, 1371, 174, 'Person']
# Record is:  [1289, 56, 1332, 88, 'Person']
# Record is:  [1287, 161, 1339, 193, 'Person']
# Record is:  [1414, 156, 1463, 187, 'Person']
# Record is:  [633, 239, 724, 311, 'Person']
# Record is:  [1445, 737, 1508, 775, 'Person']
# Record is:  [1284, 88, 1332, 116, 'Person']
# Record is:  [414, 361, 477, 415, 'Person']
# Record is:  [854, 816, 966, 892, 'Biker']
# Record is:  [1406, 179, 1463, 213, 'Person']
# 17 0 0 0
# Ground Truth:  17
# imgs/test/coupa_video3_10560.jpg
# processing time:  0.0705256462097168
# Record is:  [1448, 111, 1498, 147, 'Person']
# Record is:  [697, 262, 786, 335, 'Person']
# Record is:  [581, 341, 665, 416, 'Person']
# Record is:  [1286, 159, 1339, 192, 'Person']
# Record is:  [851, 915, 921, 983, 'Person']
# Record is:  [1333, 109, 1386, 141, 'Person']
# Record is:  [418, 32, 518, 114, 'Biker']
# Record is:  [1288, 119, 1338, 151, 'Person']
# Record is:  [1287, 55, 1333, 88, 'Person']
# Record is:  [925, 923, 995, 978, 'Person']
# Record is:  [1284, 88, 1332, 116, 'Person']
# Record is:  [1412, 157, 1463, 188, 'Person']
# Record is:  [1336, 144, 1372, 174, 'Person']
# Record is:  [1445, 736, 1511, 776, 'Person']
# Record is:  [956, 816, 1080, 901, 'Biker']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10590.jpg
# processing time:  0.07074236869812012
# Record is:  [871, 913, 940, 980, 'Person']
# Record is:  [725, 293, 811, 364, 'Person']
# Record is:  [1449, 111, 1497, 149, 'Person']
# Record is:  [942, 931, 1010, 984, 'Person']
# Record is:  [579, 339, 668, 412, 'Person']
# Record is:  [1287, 159, 1339, 194, 'Person']
# Record is:  [1288, 119, 1339, 152, 'Person']
# Record is:  [1287, 53, 1333, 88, 'Person']
# Record is:  [1333, 109, 1386, 141, 'Person']
# Record is:  [1336, 144, 1371, 174, 'Person']
# Record is:  [1284, 87, 1332, 116, 'Person']
# Record is:  [1054, 828, 1190, 912, 'Biker']
# Record is:  [310, 4, 408, 83, 'Biker']
# Record is:  [1444, 734, 1511, 777, 'Person']
# Record is:  [1413, 157, 1461, 190, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10620.jpg
# processing time:  0.07028770446777344
# Record is:  [1446, 110, 1498, 149, 'Person']
# Record is:  [1289, 117, 1338, 151, 'Person']
# Record is:  [756, 331, 842, 403, 'Person']
# Record is:  [895, 906, 965, 972, 'Person']
# Record is:  [575, 338, 671, 408, 'Person']
# Record is:  [1333, 108, 1386, 141, 'Person']
# Record is:  [1284, 156, 1338, 192, 'Person']
# Record is:  [949, 927, 1018, 981, 'Person']
# Record is:  [1286, 53, 1333, 89, 'Person']
# Record is:  [1283, 88, 1333, 117, 'Person']
# Record is:  [1334, 145, 1371, 174, 'Person']
# Record is:  [1409, 158, 1462, 190, 'Person']
# Record is:  [1149, 859, 1283, 944, 'Biker']
# Record is:  [1445, 734, 1515, 778, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10650.jpg
# processing time:  0.0706644058227539
# Record is:  [574, 334, 673, 407, 'Person']
# Record is:  [913, 905, 981, 973, 'Person']
# Record is:  [1288, 118, 1338, 152, 'Person']
# Record is:  [1445, 111, 1497, 149, 'Person']
# Record is:  [1331, 108, 1385, 143, 'Person']
# Record is:  [1410, 154, 1462, 192, 'Person']
# Record is:  [1283, 156, 1335, 192, 'Person']
# Record is:  [1280, 53, 1332, 90, 'Person']
# Record is:  [793, 365, 883, 439, 'Person']
# Record is:  [1333, 144, 1371, 174, 'Person']
# Record is:  [1283, 87, 1333, 118, 'Person']
# Record is:  [1445, 735, 1515, 777, 'Person']
# Record is:  [955, 925, 1022, 980, 'Person']
# 13 0 0 1
# Ground Truth:  14
# imgs/test/coupa_video3_10680.jpg
# processing time:  0.07148551940917969
# Record is:  [575, 331, 676, 403, 'Person']
# Record is:  [1445, 110, 1498, 151, 'Person']
# Record is:  [830, 403, 918, 475, 'Person']
# Record is:  [913, 905, 985, 973, 'Person']
# Record is:  [1330, 109, 1385, 142, 'Person']
# Record is:  [1288, 117, 1338, 151, 'Person']
# Record is:  [1281, 153, 1335, 191, 'Person']
# Record is:  [1283, 87, 1331, 118, 'Person']
# Record is:  [1281, 52, 1333, 90, 'Person']
# Record is:  [1409, 153, 1462, 192, 'Person']
# Record is:  [1332, 143, 1371, 174, 'Person']
# Record is:  [1445, 733, 1516, 780, 'Person']
# Record is:  [1242, 957, 1383, 1037, 'Biker']
# Record is:  [958, 925, 1027, 982, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10710.jpg
# processing time:  0.07036328315734863
# Record is:  [915, 905, 984, 974, 'Person']
# Record is:  [568, 328, 677, 399, 'Person']
# Record is:  [866, 423, 954, 498, 'Person']
# Record is:  [1443, 110, 1497, 150, 'Person']
# Record is:  [1330, 108, 1385, 143, 'Person']
# Record is:  [1444, 731, 1518, 781, 'Person']
# Record is:  [1289, 116, 1338, 151, 'Person']
# Record is:  [44, 843, 133, 921, 'Biker']
# Record is:  [1331, 143, 1371, 174, 'Person']
# Record is:  [1281, 153, 1335, 191, 'Person']
# Record is:  [1284, 88, 1331, 119, 'Person']
# Record is:  [1409, 154, 1461, 192, 'Person']
# Record is:  [1278, 52, 1333, 90, 'Person']
# Record is:  [969, 925, 1037, 978, 'Person']
# Record is:  [1247, 970, 1384, 1056, 'Biker']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10740.jpg
# processing time:  0.07085037231445312
# Record is:  [924, 908, 992, 974, 'Person']
# Record is:  [1331, 109, 1384, 143, 'Person']
# Record is:  [1442, 111, 1498, 152, 'Person']
# Record is:  [564, 329, 685, 397, 'Person']
# Record is:  [1283, 87, 1330, 120, 'Person']
# Record is:  [1289, 116, 1338, 151, 'Person']
# Record is:  [912, 454, 1000, 526, 'Person']
# Record is:  [1407, 153, 1463, 196, 'Person']
# Record is:  [1331, 143, 1371, 175, 'Person']
# Record is:  [1275, 52, 1332, 91, 'Person']
# Record is:  [991, 926, 1059, 980, 'Person']
# Record is:  [1279, 151, 1334, 190, 'Person']
# Record is:  [303, 851, 397, 928, 'Biker']
# Record is:  [1444, 732, 1520, 782, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10770.jpg
# processing time:  0.07298111915588379
# Record is:  [956, 472, 1043, 547, 'Person']
# Record is:  [934, 908, 1003, 975, 'Person']
# Record is:  [1330, 143, 1373, 174, 'Person']
# Record is:  [1443, 111, 1498, 154, 'Person']
# Record is:  [1328, 109, 1384, 144, 'Person']
# Record is:  [1441, 728, 1525, 783, 'Person']
# Record is:  [1408, 151, 1464, 196, 'Person']
# Record is:  [1013, 927, 1082, 981, 'Person']
# Record is:  [1275, 50, 1332, 92, 'Person']
# Record is:  [1284, 88, 1331, 120, 'Person']
# Record is:  [1287, 115, 1339, 149, 'Person']
# Record is:  [1276, 150, 1332, 190, 'Person']
# Record is:  [606, 327, 722, 396, 'Person']
# Record is:  [564, 846, 659, 924, 'Biker']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10800.jpg
# processing time:  0.07079124450683594
# Record is:  [992, 482, 1081, 554, 'Person']
# Record is:  [1408, 151, 1464, 197, 'Person']
# Record is:  [1443, 111, 1497, 154, 'Person']
# Record is:  [642, 323, 761, 393, 'Person']
# Record is:  [1330, 143, 1374, 174, 'Person']
# Record is:  [1882, 817, 1959, 884, 'Person']
# Record is:  [1441, 730, 1524, 783, 'Person']
# Record is:  [1329, 109, 1385, 144, 'Person']
# Record is:  [954, 916, 1023, 982, 'Person']
# Record is:  [1035, 928, 1104, 983, 'Person']
# Record is:  [837, 837, 931, 912, 'Biker']
# Record is:  [1287, 115, 1339, 149, 'Person']
# Record is:  [1283, 88, 1331, 121, 'Person']
# Record is:  [1277, 149, 1333, 190, 'Person']
# Record is:  [1275, 50, 1333, 93, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10830.jpg
# processing time:  0.07097744941711426
# Record is:  [1862, 810, 1938, 877, 'Person']
# Record is:  [1405, 152, 1462, 199, 'Person']
# Record is:  [1439, 110, 1498, 154, 'Person']
# Record is:  [1055, 506, 1144, 577, 'Person']
# Record is:  [980, 931, 1049, 999, 'Person']
# Record is:  [678, 310, 796, 377, 'Person']
# Record is:  [1327, 108, 1386, 144, 'Person']
# Record is:  [1327, 143, 1374, 175, 'Person']
# Record is:  [1285, 88, 1331, 122, 'Person']
# Record is:  [1443, 730, 1527, 785, 'Person']
# Record is:  [1287, 112, 1339, 149, 'Person']
# Record is:  [1274, 50, 1332, 92, 'Person']
# Record is:  [1275, 147, 1333, 191, 'Person']
# Record is:  [1099, 853, 1194, 930, 'Biker']
# Record is:  [1044, 925, 1111, 980, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10860.jpg
# processing time:  0.07061314582824707
# Record is:  [1831, 805, 1907, 874, 'Person']
# Record is:  [1404, 151, 1462, 201, 'Person']
# Record is:  [1328, 141, 1374, 175, 'Person']
# Record is:  [1101, 523, 1189, 596, 'Person']
# Record is:  [1440, 111, 1498, 157, 'Person']
# Record is:  [1327, 109, 1386, 146, 'Person']
# Record is:  [715, 295, 833, 364, 'Person']
# Record is:  [1283, 87, 1328, 122, 'Person']
# Record is:  [1442, 727, 1525, 785, 'Person']
# Record is:  [1287, 113, 1339, 149, 'Person']
# Record is:  [1377, 864, 1469, 941, 'Biker']
# Record is:  [1011, 942, 1081, 1009, 'Person']
# Record is:  [1275, 50, 1332, 91, 'Person']
# Record is:  [1274, 146, 1332, 188, 'Person']
# Record is:  [1052, 923, 1122, 981, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10890.jpg
# processing time:  0.0712747573852539
# Record is:  [1405, 149, 1462, 201, 'Person']
# Record is:  [1152, 532, 1240, 606, 'Person']
# Record is:  [740, 279, 857, 351, 'Person']
# Record is:  [1786, 805, 1864, 873, 'Person']
# Record is:  [1443, 728, 1530, 787, 'Person']
# Record is:  [1065, 947, 1133, 1014, 'Person']
# Record is:  [1440, 110, 1497, 157, 'Person']
# Record is:  [1326, 140, 1374, 174, 'Person']
# Record is:  [1325, 109, 1385, 147, 'Person']
# Record is:  [1284, 87, 1327, 122, 'Person']
# Record is:  [1631, 883, 1724, 958, 'Biker']
# Record is:  [1286, 113, 1338, 150, 'Person']
# Record is:  [1266, 46, 1333, 94, 'Person']
# Record is:  [1270, 145, 1331, 188, 'Person']
# Record is:  [1085, 923, 1155, 976, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10920.jpg
# processing time:  0.07037997245788574
# Record is:  [1436, 110, 1498, 160, 'Person']
# Record is:  [1741, 799, 1820, 869, 'Person']
# Record is:  [1402, 149, 1463, 200, 'Person']
# Record is:  [1442, 726, 1531, 788, 'Person']
# Record is:  [1205, 541, 1295, 613, 'Person']
# Record is:  [1113, 949, 1182, 1016, 'Person']
# Record is:  [1888, 888, 1969, 964, 'Biker']
# Record is:  [1325, 141, 1375, 174, 'Person']
# Record is:  [1326, 108, 1385, 148, 'Person']
# Record is:  [1283, 88, 1328, 124, 'Person']
# Record is:  [756, 267, 876, 337, 'Person']
# Record is:  [1264, 45, 1333, 95, 'Person']
# Record is:  [1286, 111, 1338, 149, 'Person']
# Record is:  [1270, 142, 1331, 188, 'Person']
# Record is:  [1114, 914, 1184, 970, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_10950.jpg
# processing time:  0.07085323333740234
# Record is:  [1702, 802, 1779, 872, 'Person']
# Record is:  [1145, 942, 1216, 1010, 'Person']
# Record is:  [1402, 149, 1462, 201, 'Person']
# Record is:  [1438, 111, 1497, 159, 'Person']
# Record is:  [1442, 725, 1530, 786, 'Person']
# Record is:  [1325, 140, 1375, 175, 'Person']
# Record is:  [781, 259, 896, 329, 'Person']
# Record is:  [1326, 108, 1386, 148, 'Person']
# Record is:  [1283, 88, 1328, 125, 'Person']
# Record is:  [1286, 111, 1338, 149, 'Person']
# Record is:  [1241, 543, 1324, 616, 'Person']
# Record is:  [1264, 44, 1333, 94, 'Person']
# Record is:  [1266, 142, 1330, 188, 'Person']
# Record is:  [1156, 914, 1224, 970, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_10980.jpg
# processing time:  0.07077693939208984
# Record is:  [1402, 150, 1462, 202, 'Person']
# Record is:  [1442, 725, 1534, 790, 'Person']
# Record is:  [1437, 110, 1498, 160, 'Person']
# Record is:  [1644, 806, 1721, 873, 'Person']
# Record is:  [1186, 941, 1253, 1007, 'Person']
# Record is:  [1261, 44, 1332, 94, 'Person']
# Record is:  [1325, 140, 1374, 175, 'Person']
# Record is:  [1283, 88, 1328, 124, 'Person']
# Record is:  [1326, 109, 1387, 148, 'Person']
# Record is:  [805, 251, 924, 320, 'Person']
# Record is:  [1297, 546, 1383, 619, 'Person']
# Record is:  [1201, 906, 1269, 963, 'Person']
# Record is:  [1286, 111, 1338, 149, 'Person']
# Record is:  [1266, 142, 1331, 188, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_11010.jpg
# processing time:  0.0703892707824707
# Record is:  [1402, 146, 1464, 202, 'Person']
# Record is:  [1587, 806, 1662, 873, 'Person']
# Record is:  [1433, 109, 1499, 161, 'Person']
# Record is:  [1443, 725, 1534, 789, 'Person']
# Record is:  [1325, 107, 1386, 149, 'Person']
# Record is:  [1222, 936, 1292, 1004, 'Person']
# Record is:  [1264, 44, 1331, 96, 'Person']
# Record is:  [1240, 907, 1309, 962, 'Person']
# Record is:  [1280, 85, 1328, 127, 'Person']
# Record is:  [1322, 137, 1376, 177, 'Person']
# Record is:  [1264, 141, 1331, 186, 'Person']
# Record is:  [1285, 110, 1338, 150, 'Person']
# Record is:  [1204, 63, 1268, 118, 'Person']
# Record is:  [847, 231, 943, 287, 'Person']
# Record is:  [1369, 586, 1431, 651, 'Person']
# 15 0 0 0
# Ground Truth:  15
# imgs/test/coupa_video3_11040.jpg
# processing time:  0.07287192344665527
# Record is:  [1433, 109, 1497, 160, 'Person']
# Record is:  [1401, 147, 1463, 202, 'Person']
# Record is:  [1264, 939, 1332, 1004, 'Person']
# Record is:  [1276, 910, 1350, 962, 'Person']
# Record is:  [1325, 107, 1386, 149, 'Person']
# Record is:  [1533, 803, 1612, 874, 'Person']
# Record is:  [895, 207, 991, 261, 'Person']
# Record is:  [1424, 583, 1488, 650, 'Person']
# Record is:  [1261, 42, 1332, 96, 'Person']
# Record is:  [1322, 138, 1377, 176, 'Person']
# Record is:  [1266, 141, 1331, 186, 'Person']
# Record is:  [1280, 86, 1328, 126, 'Person']
# Record is:  [1287, 111, 1339, 150, 'Person']
# Record is:  [1204, 65, 1268, 118, 'Person']
# 14 0 0 0
# Ground Truth:  14
# imgs/test/coupa_video3_11070.jpg
# processing time:  0.07050704956054688
# Record is:  [1402, 147, 1465, 202, 'Person']
# Record is:  [1303, 938, 1373, 1006, 'Person']
# Record is:  [924, 200, 1023, 254, 'Person']
# Record is:  [1434, 109, 1498, 160, 'Person']
# Record is:  [1480, 800, 1559, 872, 'Person']
# Record is:  [1326, 106, 1386, 149, 'Person']
# Record is:  [1261, 42, 1333, 96, 'Person']
# Record is:  [1322, 138, 1375, 176, 'Person']
# Record is:  [1265, 141, 1331, 186, 'Person']
# Record is:  [1280, 86, 1328, 126, 'Person']
# Record is:  [1314, 909, 1389, 966, 'Person']
# Record is:  [1286, 109, 1338, 150, 'Person']
# Record is:  [1204, 66, 1266, 118, 'Person']
# 13 0 0 0
# Ground Truth:  13
# imgs/test/coupa_video3_11100.jpg
# processing time:  0.07123041152954102
# Record is:  [1426, 797, 1503, 873, 'Person']
# Record is:  [962, 202, 1059, 260, 'Person']
# Record is:  [1402, 147, 1465, 202, 'Person']
# Record is:  [1326, 107, 1386, 149, 'Person']
# Record is:  [1354, 912, 1433, 965, 'Person']
# Record is:  [1341, 939, 1413, 1007, 'Person']
# Record is:  [1434, 109, 1497, 160, 'Person']
# Record is:  [1264, 43, 1335, 96, 'Person']
# Record is:  [1279, 85, 1330, 126, 'Person']
# Record is:  [1322, 138, 1377, 176, 'Person']
# Record is:  [1268, 141, 1333, 186, 'Person']
# Record is:  [1285, 110, 1339, 149, 'Person']
# 12 0 0 1
# Ground Truth:  13
# imgs/test/coupa_video3_11130.jpg
# processing time:  0.07132387161254883
# Record is:  [1277, 86, 1330, 126, 'Person']
# 1 0 0 12
# Ground Truth:  13
# imgs/test/coupa_video3_11160.jpg
# processing time:  0.07050108909606934
# Record is:  [1405, 147, 1465, 200, 'Person']
# Record is:  [1284, 115, 1340, 151, 'Person']
# Record is:  [1329, 109, 1383, 145, 'Person']
# Record is:  [1040, 215, 1124, 276, 'Person']
# Record is:  [1330, 142, 1373, 175, 'Person']
# Record is:  [1436, 110, 1498, 158, 'Person']
# Record is:  [1282, 88, 1329, 121, 'Person']
# Record is:  [1445, 728, 1527, 786, 'Person']
# Record is:  [1276, 147, 1335, 190, 'Person']
# Record is:  [1325, 793, 1416, 866, 'Person']
# Record is:  [1418, 927, 1491, 982, 'Person']
# Record is:  [1412, 956, 1485, 1008, 'Person']
# Record is:  [1276, 50, 1331, 92, 'Person']
# 12 0 1 0
# Ground Truth:  13
# imgs/test/coupa_video3_11190.jpg
# processing time:  0.07036280632019043
# Record is:  [1329, 109, 1381, 144, 'Person']
# Record is:  [1276, 799, 1361, 867, 'Person']
# Record is:  [1283, 115, 1339, 152, 'Person']
# Record is:  [1408, 147, 1464, 195, 'Person']
# Record is:  [1441, 729, 1522, 782, 'Person']
# Record is:  [1329, 141, 1370, 176, 'Person']
# Record is:  [1441, 110, 1500, 153, 'Person']
# Record is:  [1282, 87, 1330, 121, 'Person']
# Record is:  [1274, 50, 1330, 92, 'Person']
# Record is:  [582, 331, 684, 391, 'Person']
# Record is:  [1280, 149, 1333, 191, 'Person']
# Record is:  [1470, 916, 1551, 972, 'Person']
# Record is:  [415, 361, 478, 417, 'Person']
# Record is:  [1089, 234, 1148, 296, 'Person']
# 11 0 3 0
# Ground Truth:  13
# imgs/test/coupa_video3_11220.jpg
# processing time:  0.07365775108337402
# Record is:  [1412, 151, 1462, 191, 'Person']
# Record is:  [1284, 88, 1331, 120, 'Person']
# Record is:  [1443, 110, 1500, 152, 'Person']
# Record is:  [1275, 52, 1329, 92, 'Person']
# Record is:  [1234, 800, 1305, 853, 'Person']
# Record is:  [1329, 144, 1370, 175, 'Person']
# Record is:  [1328, 110, 1384, 142, 'Person']
# Record is:  [1284, 154, 1335, 190, 'Person']
# Record is:  [1511, 918, 1585, 967, 'Person']
# Record is:  [1442, 729, 1530, 785, 'Person']
# Record is:  [1287, 115, 1343, 148, 'Person']
# Record is:  [1102, 241, 1172, 306, 'Biker']
# 10 1 1 1
# Ground Truth:  13
# imgs/test/coupa_video3_11250.jpg
# processing time:  0.07205939292907715
# Record is:  [1413, 154, 1463, 192, 'Person']
# Record is:  [1441, 110, 1500, 151, 'Person']
# Record is:  [1184, 800, 1262, 856, 'Person']
# Record is:  [1284, 116, 1339, 150, 'Person']
# Record is:  [1328, 109, 1382, 143, 'Person']
# Record is:  [1330, 143, 1369, 175, 'Person']
# Record is:  [1282, 88, 1331, 120, 'Person']
# Record is:  [1282, 153, 1337, 189, 'Person']
# Record is:  [1147, 250, 1241, 310, 'Person']
# Record is:  [1533, 945, 1609, 994, 'Person']
# Record is:  [1276, 52, 1331, 91, 'Person']
# Record is:  [1441, 733, 1516, 780, 'Person']
# Record is:  [413, 362, 474, 416, 'Person']
# Record is:  [1549, 921, 1617, 973, 'Person']
# 12 0 2 0
# Ground Truth:  13
# imgs/test/coupa_video3_11280.jpg
# processing time:  0.07150053977966309
# Record is:  [1328, 109, 1383, 142, 'Person']
# Record is:  [1411, 152, 1464, 192, 'Person']
# Record is:  [1445, 110, 1499, 154, 'Person']
# Record is:  [1284, 88, 1332, 119, 'Person']
# Record is:  [1286, 116, 1338, 149, 'Person']
# Record is:  [1277, 52, 1331, 91, 'Person']
# Record is:  [1444, 732, 1523, 782, 'Person']
# Record is:  [1597, 916, 1669, 968, 'Person']
# Record is:  [1329, 141, 1369, 173, 'Person']
# Record is:  [1142, 793, 1212, 842, 'Person']
# Record is:  [1213, 253, 1276, 309, 'Person']
# Record is:  [1583, 941, 1666, 991, 'Person']
# Record is:  [584, 333, 684, 392, 'Person']
# Record is:  [1277, 152, 1335, 190, 'Person']
# 12 0 2 0
# Ground Truth:  13
# imgs/test/coupa_video3_11310.jpg
# processing time:  0.07066988945007324
# Record is:  [1407, 150, 1462, 199, 'Person']
# Record is:  [1283, 87, 1329, 120, 'Person']
# Record is:  [1091, 790, 1157, 849, 'Person']
# Record is:  [1286, 116, 1339, 150, 'Person']
# Record is:  [1442, 111, 1499, 157, 'Person']
# Record is:  [1328, 109, 1385, 144, 'Person']
# Record is:  [1441, 729, 1524, 784, 'Person']
# Record is:  [1242, 267, 1335, 339, 'Person']
# Record is:  [1643, 914, 1715, 970, 'Person']
# Record is:  [1328, 141, 1372, 172, 'Person']
# Record is:  [1609, 953, 1685, 1015, 'Person']
# Record is:  [1275, 50, 1333, 92, 'Person']
# Record is:  [1272, 147, 1334, 188, 'Person']
# Record is:  [1599, 966, 1669, 1031, 'Person']
# 13 0 1 0
# Ground Truth:  13
# imgs/test/coupa_video3_11340.jpg
# processing time:  0.07118487358093262
# Record is:  [1032, 794, 1108, 853, 'Person']
# Record is:  [1402, 147, 1464, 201, 'Person']
# Record is:  [1438, 110, 1500, 158, 'Person']
# Record is:  [1585, 940, 1661, 998, 'Person']
# Record is:  [17, 918, 116, 991, 'Biker']
# Record is:  [1328, 109, 1386, 146, 'Person']
# Record is:  [1284, 87, 1329, 122, 'Person']
# Record is:  [1328, 142, 1373, 175, 'Person']
# Record is:  [1286, 114, 1340, 150, 'Person']
# Record is:  [1270, 283, 1335, 356, 'Person']
# Record is:  [1440, 729, 1523, 783, 'Person']
# Record is:  [1273, 52, 1333, 95, 'Person']
# Record is:  [1273, 147, 1333, 189, 'Person']
# Record is:  [1677, 924, 1753, 975, 'Person']
# 12 0 2 0
# Ground Truth:  14
# imgs/test/coupa_video3_11370.jpg
# processing time:  0.07065415382385254
# Record is:  [1402, 146, 1464, 200, 'Person']
# Record is:  [1690, 960, 1761, 1022, 'Person']
# Record is:  [1327, 107, 1382, 146, 'Person']
# Record is:  [1287, 113, 1339, 150, 'Person']
# Record is:  [1433, 111, 1498, 158, 'Person']
# Record is:  [990, 785, 1059, 844, 'Person']
# Record is:  [1310, 273, 1394, 341, 'Person']
# Record is:  [1572, 894, 1641, 961, 'Person']
# Record is:  [1283, 86, 1329, 123, 'Person']
# Record is:  [113, 925, 208, 1000, 'Biker']
# Record is:  [1447, 734, 1521, 779, 'Person']
# Record is:  [1273, 49, 1330, 94, 'Person']
# Record is:  [1274, 145, 1333, 188, 'Person']
# 12 0 1 2
# Ground Truth:  15
# imgs/test/coupa_video3_11400.jpg
# processing time:  0.07197308540344238
# Record is:  [1576, 839, 1668, 907, 'Person']
# Record is:  [936, 784, 1012, 849, 'Person']
# Record is:  [1404, 142, 1468, 197, 'Person']
# Record is:  [1832, 766, 1914, 829, 'Person']
# Record is:  [1327, 108, 1383, 147, 'Person']
# Record is:  [1358, 278, 1449, 341, 'Person']
# Record is:  [1436, 111, 1500, 160, 'Person']
# Record is:  [221, 929, 320, 1007, 'Biker']
# Record is:  [1275, 50, 1330, 96, 'Person']
# Record is:  [1286, 113, 1339, 151, 'Person']
# Record is:  [1326, 140, 1374, 175, 'Person']
# Record is:  [1273, 143, 1332, 187, 'Person']
# Record is:  [1450, 732, 1524, 782, 'Person']
# Record is:  [1282, 86, 1330, 125, 'Person']
# 13 0 1 2
# Ground Truth:  16
# imgs/test/coupa_video3_11430.jpg
# processing time:  0.07141470909118652
# Record is:  [1401, 146, 1466, 201, 'Person']
# Record is:  [1438, 110, 1499, 158, 'Person']
# Record is:  [887, 781, 957, 854, 'Person']
# Record is:  [1285, 115, 1337, 149, 'Person']
# Record is:  [1269, 51, 1331, 97, 'Person']
# Record is:  [314, 922, 418, 997, 'Biker']
# Record is:  [1788, 930, 1863, 981, 'Person']
# Record is:  [1281, 86, 1329, 121, 'Person']
# Record is:  [1439, 728, 1519, 785, 'Person']
# Record is:  [1775, 768, 1862, 839, 'Person']
# Record is:  [1328, 109, 1380, 147, 'Person']
# Record is:  [1395, 278, 1470, 326, 'Person']
# Record is:  [1327, 139, 1371, 173, 'Person']
# Record is:  [1780, 967, 1848, 1010, 'Person']
# Record is:  [1272, 147, 1332, 187, 'Person']
# Record is:  [1596, 792, 1656, 851, 'Biker']
# 14 1 1 0
# Ground Truth:  16
# imgs/test/coupa_video3_11460.jpg
# processing time:  0.0705878734588623
# Record is:  [1330, 108, 1385, 141, 'Person']
# Record is:  [1284, 88, 1330, 119, 'Person']
# Record is:  [1288, 116, 1337, 150, 'Person']
# Record is:  [1331, 141, 1369, 174, 'Person']
# Record is:  [1282, 52, 1332, 90, 'Person']
# Record is:  [410, 921, 515, 989, 'Biker']
# Record is:  [1443, 111, 1498, 154, 'Person']
# Record is:  [580, 334, 680, 399, 'Person']
# Record is:  [1406, 151, 1465, 199, 'Person']
# Record is:  [1275, 148, 1334, 190, 'Person']
# Record is:  [1417, 320, 1492, 367, 'Person']
# Record is:  [1814, 927, 1899, 985, 'Person']
# Record is:  [1420, 274, 1500, 330, 'Person']
# Record is:  [1448, 727, 1530, 784, 'Person']
# Record is:  [1736, 787, 1809, 849, 'Person']
# Record is:  [841, 783, 907, 845, 'Person']
# 13 0 3 0
# Ground Truth:  16
# imgs/test/coupa_video3_11490.jpg
# processing time:  0.07068133354187012
# Record is:  [1442, 110, 1499, 155, 'Person']
# Record is:  [1412, 149, 1460, 192, 'Person']
# Record is:  [1284, 88, 1330, 119, 'Person']
# Record is:  [790, 782, 861, 848, 'Person']
# Record is:  [1328, 109, 1383, 142, 'Person']
# Record is:  [1330, 143, 1369, 174, 'Person']
# Record is:  [1282, 52, 1333, 90, 'Person']
# Record is:  [513, 916, 609, 978, 'Biker']
# Record is:  [1452, 273, 1538, 336, 'Person']
# Record is:  [1285, 116, 1338, 150, 'Person']
# Record is:  [1445, 731, 1517, 778, 'Person']
# Record is:  [1278, 154, 1334, 189, 'Person']
# Record is:  [413, 361, 476, 414, 'Person']
# Record is:  [1849, 926, 1927, 984, 'Person']
# 12 0 2 2
# Ground Truth:  16
# imgs/test/coupa_video3_11520.jpg
# processing time:  0.07101702690124512
# Record is:  [1329, 109, 1380, 142, 'Person']
# Record is:  [1283, 87, 1329, 119, 'Person']
# Record is:  [1328, 142, 1368, 175, 'Person']
# Record is:  [1276, 51, 1329, 92, 'Person']
# Record is:  [1442, 727, 1517, 780, 'Person']
# Record is:  [734, 792, 810, 847, 'Person']
# Record is:  [1285, 117, 1337, 150, 'Person']
# Record is:  [1445, 110, 1499, 154, 'Person']
# Record is:  [615, 913, 702, 971, 'Biker']
# Record is:  [1405, 149, 1461, 197, 'Person']
# Record is:  [1281, 156, 1336, 188, 'Person']
# Record is:  [1639, 790, 1711, 852, 'Person']
# Record is:  [1920, 918, 1971, 974, 'Person']
# Record is:  [1890, 973, 1949, 1015, 'Person']
# 13 0 1 1
# Ground Truth:  15
# imgs/test/coupa_video3_11550.jpg
# processing time:  0.0709080696105957
# Record is:  [1329, 108, 1382, 142, 'Person']
# Record is:  [687, 812, 763, 873, 'Person']
# Record is:  [1410, 154, 1461, 190, 'Person']
# Record is:  [1330, 144, 1369, 174, 'Person']
# Record is:  [1284, 52, 1332, 89, 'Person']
# Record is:  [1283, 87, 1329, 117, 'Person']
# Record is:  [1282, 159, 1336, 192, 'Person']
# Record is:  [704, 905, 784, 972, 'Biker']
# Record is:  [1443, 120, 1494, 160, 'Person']
# Record is:  [1285, 117, 1337, 150, 'Person']
# Record is:  [1597, 790, 1663, 847, 'Person']
# Record is:  [1448, 734, 1518, 778, 'Person']
# Record is:  [1932, 924, 1978, 981, 'Person']
# Record is:  [1449, 85, 1501, 125, 'Person']
# 13 0 1 2
# Ground Truth:  16
# imgs/test/coupa_video3_11580.jpg
# processing time:  0.07125091552734375
# Record is:  [1401, 155, 1465, 200, 'Person']
# Record is:  [1330, 108, 1385, 146, 'Person']
# Record is:  [804, 912, 876, 974, 'Biker']
# Record is:  [1438, 109, 1497, 153, 'Person']
# Record is:  [1329, 142, 1371, 174, 'Person']
# Record is:  [1283, 87, 1329, 120, 'Person']
# Record is:  [1286, 116, 1340, 149, 'Person']
# Record is:  [638, 825, 719, 897, 'Person']
# Record is:  [1273, 150, 1335, 192, 'Person']
# Record is:  [1437, 729, 1517, 776, 'Person']
# Record is:  [1532, 790, 1604, 847, 'Person']
# Record is:  [1414, 85, 1465, 125, 'Person']
# Record is:  [1278, 52, 1330, 91, 'Person']
# 12 0 1 1
# Ground Truth:  14
# imgs/test/coupa_video3_11610.jpg
# processing time:  0.07091188430786133
# Record is:  [593, 847, 669, 915, 'Person']
# Record is:  [1332, 109, 1379, 146, 'Person']
# Record is:  [1440, 113, 1502, 156, 'Person']
# Record is:  [1331, 140, 1375, 176, 'Person']
# Record is:  [1285, 114, 1338, 150, 'Person']
# Record is:  [1393, 143, 1463, 197, 'Person']
# Record is:  [1386, 107, 1446, 152, 'Person']
# Record is:  [1283, 87, 1333, 122, 'Person']
# Record is:  [880, 916, 980, 985, 'Biker']
# Record is:  [1485, 801, 1567, 858, 'Person']
# Record is:  [1281, 150, 1337, 188, 'Person']
# Record is:  [1276, 50, 1332, 92, 'Person']
# 12 0 0 2
# Ground Truth:  14
# imgs/test/coupa_video3_11640.jpg
# processing time:  0.07066488265991211
# Record is:  [1440, 110, 1497, 155, 'Person']
# Record is:  [968, 920, 1061, 992, 'Biker']
# Record is:  [1404, 147, 1462, 195, 'Person']
# Record is:  [1332, 108, 1380, 146, 'Person']
# Record is:  [1452, 797, 1525, 856, 'Person']
# Record is:  [1286, 116, 1337, 150, 'Person']
# Record is:  [1334, 145, 1385, 178, 'Person']
# Record is:  [557, 872, 617, 943, 'Person']
# Record is:  [579, 331, 678, 396, 'Person']
# Record is:  [1283, 87, 1330, 120, 'Person']
# Record is:  [1347, 148, 1402, 182, 'Person']
# Record is:  [1283, 51, 1331, 90, 'Person']
# Record is:  [1282, 154, 1331, 191, 'Person']
# Record is:  [416, 361, 478, 415, 'Person']
# 12 0 2 0
# Ground Truth:  14
# imgs/test/coupa_video3_11670.jpg
# processing time:  0.0705714225769043
# Record is:  [1064, 929, 1163, 997, 'Biker']
# Record is:  [1442, 109, 1503, 156, 'Person']
# Record is:  [1282, 117, 1335, 152, 'Person']
# Record is:  [1405, 149, 1461, 196, 'Person']
# Record is:  [1329, 109, 1380, 145, 'Person']
# Record is:  [1277, 53, 1328, 93, 'Person']
# Record is:  [1550, 981, 1626, 1034, 'Person']
# Record is:  [1328, 143, 1369, 178, 'Person']
# Record is:  [1281, 151, 1335, 189, 'Person']
# Record is:  [1281, 88, 1328, 120, 'Person']
# Record is:  [516, 885, 582, 944, 'Person']
# Record is:  [418, 362, 479, 414, 'Person']
# Record is:  [1387, 799, 1463, 862, 'Person']
# Record is:  [1318, 175, 1371, 215, 'Person']
# 13 0 1 1
# Ground Truth:  15
# imgs/test/coupa_video3_11700.jpg
# processing time:  0.07094264030456543
# Record is:  [1551, 933, 1633, 990, 'Person']
# Record is:  [1329, 108, 1378, 145, 'Person']
# Record is:  [1442, 111, 1500, 155, 'Person']
# Record is:  [1412, 148, 1462, 193, 'Person']
# Record is:  [1282, 153, 1337, 194, 'Person']
# Record is:  [1285, 117, 1336, 151, 'Person']
# Record is:  [1280, 52, 1331, 93, 'Person']
# Record is:  [1329, 142, 1372, 175, 'Person']
# Record is:  [1144, 931, 1254, 1004, 'Biker']
# Record is:  [1282, 240, 1340, 299, 'Person']
# Record is:  [474, 916, 530, 967, 'Person']
# Record is:  [1283, 87, 1331, 119, 'Person']
# Record is:  [1446, 729, 1520, 783, 'Person']
# 11 0 2 2
# Ground Truth:  15
# imgs/test/coupa_video3_11730.jpg
# processing time:  0.07082271575927734
# Record is:  [1550, 876, 1637, 948, 'Person']
# Record is:  [1413, 153, 1463, 189, 'Person']
# Record is:  [1445, 112, 1503, 156, 'Person']
# Record is:  [1330, 109, 1379, 146, 'Person']
# Record is:  [1282, 805, 1377, 873, 'Person']
# Record is:  [1330, 143, 1369, 176, 'Person']
# Record is:  [417, 938, 490, 993, 'Person']
# Record is:  [414, 362, 476, 416, 'Person']
# Record is:  [1286, 116, 1338, 150, 'Person']
# Record is:  [1284, 53, 1330, 90, 'Person']
# Record is:  [1282, 150, 1337, 188, 'Person']
# Record is:  [1478, 24, 1526, 55, 'Person']
# Record is:  [1249, 252, 1300, 294, 'Person']
# Record is:  [1246, 220, 1297, 254, 'Person']
# Record is:  [1285, 87, 1332, 116, 'Person']
# Record is:  [1224, 931, 1321, 993, 'Biker']
# 13 0 3 0
# Ground Truth:  15
# imgs/test/coupa_video3_11760.jpg
# processing time:  0.07121896743774414
# Record is:  [384, 957, 446, 1004, 'Person']
# Record is:  [1283, 87, 1332, 117, 'Person']
# Record is:  [1443, 112, 1501, 157, 'Person']
# Record is:  [1329, 109, 1380, 144, 'Person']
# Record is:  [1285, 54, 1332, 91, 'Person']
# Record is:  [1332, 144, 1369, 175, 'Person']
# Record is:  [1286, 118, 1340, 152, 'Person']
# Record is:  [1404, 149, 1467, 197, 'Person']
# Record is:  [1249, 813, 1330, 863, 'Person']
# Record is:  [1285, 156, 1338, 193, 'Person']
# Record is:  [1450, 737, 1510, 775, 'Person']
# Record is:  [414, 362, 478, 417, 'Person']
# Record is:  [1206, 279, 1262, 314, 'Person']
# Record is:  [1307, 936, 1417, 1001, 'Biker']
# 12 0 2 2
# Ground Truth:  16
# imgs/test/coupa_video3_11790.jpg
# processing time:  0.07115530967712402
# Record is:  [1204, 816, 1276, 869, 'Person']
# Record is:  [324, 970, 400, 1035, 'Person']
# Record is:  [1332, 109, 1380, 143, 'Person']
# Record is:  [1286, 54, 1333, 90, 'Person']
# Record is:  [1156, 317, 1234, 372, 'Person']
# Record is:  [1287, 157, 1341, 191, 'Person']
# Record is:  [1329, 143, 1368, 175, 'Person']
# Record is:  [1445, 113, 1499, 156, 'Person']
# Record is:  [414, 360, 484, 416, 'Person']
# Record is:  [1288, 117, 1339, 151, 'Person']
# Record is:  [1409, 151, 1466, 198, 'Person']
# Record is:  [1286, 89, 1332, 118, 'Person']
# Record is:  [1454, 736, 1511, 773, 'Person']
# Record is:  [1160, 258, 1233, 307, 'Person']
# Record is:  [1396, 938, 1517, 1003, 'Biker']
# Record is:  [1568, 769, 1627, 832, 'Person']
# 14 0 2 0
# Ground Truth:  15
# imgs/test/coupa_video3_11820.jpg
# processing time:  0.07116913795471191
# Record is:  [1287, 120, 1338, 153, 'Person']
# Record is:  [1444, 109, 1500, 152, 'Person']
# Record is:  [1330, 109, 1381, 145, 'Person']
# Record is:  [1122, 298, 1185, 353, 'Person']
# Record is:  [1282, 53, 1331, 91, 'Person']
# Record is:  [1412, 153, 1463, 194, 'Person']
# Record is:  [1330, 143, 1368, 174, 'Person']
# Record is:  [1171, 818, 1241, 876, 'Person']
# Record is:  [415, 364, 475, 417, 'Person']
# Record is:  [1282, 152, 1336, 187, 'Person']
# Record is:  [1516, 937, 1605, 998, 'Person']
# Record is:  [1563, 719, 1638, 779, 'Person']
# Record is:  [294, 1011, 348, 1052, 'Person']
# Record is:  [1124, 344, 1190, 394, 'Person']
# Record is:  [296, 991, 345, 1034, 'Person']
# Record is:  [1282, 87, 1329, 118, 'Person']
# 14 1 1 0
# Ground Truth:  15
# imgs/test/coupa_video3_11850.jpg
# processing time:  0.07131648063659668
# Record is:  [1329, 110, 1380, 146, 'Person']
# Record is:  [1287, 117, 1338, 151, 'Person']
# Record is:  [1329, 144, 1370, 175, 'Person']
# Record is:  [1279, 53, 1332, 93, 'Person']
# Record is:  [1443, 109, 1500, 152, 'Person']
# Record is:  [1407, 151, 1466, 201, 'Person']
# Record is:  [1282, 148, 1338, 186, 'Person']
# Record is:  [1281, 87, 1331, 120, 'Person']
# Record is:  [1101, 330, 1164, 399, 'Person']
# Record is:  [254, 1012, 308, 1075, 'Person']
# Record is:  [1117, 817, 1184, 879, 'Biker']
# Record is:  [1604, 944, 1711, 1007, 'Biker']
# 11 1 0 3
# Ground Truth:  15
# imgs/test/coupa_video3_11880.jpg
# processing time:  0.07071185111999512
# Record is:  [1333, 108, 1378, 146, 'Person']
# Record is:  [1327, 142, 1371, 177, 'Person']
# Record is:  [1288, 114, 1336, 150, 'Person']
# Record is:  [1444, 111, 1502, 155, 'Person']
# Record is:  [1409, 150, 1464, 194, 'Person']
# Record is:  [206, 1036, 259, 1086, 'Person']
# Record is:  [1056, 405, 1122, 468, 'Person']
# Record is:  [1448, 741, 1506, 776, 'Person']
# Record is:  [1282, 154, 1337, 189, 'Person']
# Record is:  [1060, 824, 1134, 895, 'Biker']
# Record is:  [1283, 87, 1330, 121, 'Person']
# Record is:  [1277, 52, 1329, 94, 'Person']
# Record is:  [579, 333, 667, 397, 'Person']
# 10 1 2 1
# Ground Truth:  14
# imgs/test/coupa_video3_11910.jpg
# processing time:  0.07102298736572266
# Record is:  [1332, 108, 1377, 145, 'Person']
# Record is:  [1443, 110, 1502, 155, 'Person']
# Record is:  [1329, 141, 1366, 175, 'Person']
# Record is:  [1022, 829, 1098, 894, 'Person']
# Record is:  [1287, 116, 1335, 153, 'Person']
# Record is:  [1415, 152, 1462, 190, 'Person']
# Record is:  [1282, 88, 1328, 119, 'Person']
# Record is:  [1285, 157, 1335, 191, 'Person']
# Record is:  [1812, 919, 1914, 981, 'Biker']
# Record is:  [416, 363, 475, 418, 'Person']
# 9 0 1 4
# Ground Truth:  14
# imgs/test/coupa_video3_11940.jpg
# processing time:  0.07137846946716309
# Record is:  [969, 834, 1042, 894, 'Person']
# Record is:  [1330, 109, 1382, 144, 'Person']
# Record is:  [1445, 112, 1498, 153, 'Person']
# ...
# Record is:  [891, 1776, 936, 1869, 'Biker']
# Record is:  [732, 864, 784, 926, 'Biker']
# 1 0 1 2
# Ground Truth:  4
# imgs/test/little_video1_7800.jpg
# processing time:  0.07470703125
# Record is:  [562, 865, 623, 929, 'Biker']
# Record is:  [40, 1172, 86, 1256, 'Person']
# Record is:  [921, 1778, 958, 1854, 'Person']
# 1 1 1 1
# Ground Truth:  4
# imgs/test/little_video1_7830.jpg
# processing time:  0.07444572448730469
# Record is:  [1193, 815, 1256, 917, 'Biker']
# Record is:  [402, 869, 452, 934, 'Biker']
# Record is:  [961, 1766, 1007, 1831, 'Person']
# 2 1 0 2
# Ground Truth:  5
# imgs/test/little_video1_7860.jpg
# processing time:  0.07432198524475098
# Record is:  [994, 825, 1047, 907, 'Biker']
# 1 0 0 4
# Ground Truth:  5
# imgs/test/little_video1_7890.jpg
# processing time:  0.07435965538024902
# Record is:  [806, 828, 854, 899, 'Biker']
# Record is:  [985, 884, 1038, 941, 'Biker']
# 2 0 0 3
# Ground Truth:  5
# imgs/test/little_video1_7920.jpg
# processing time:  0.07466411590576172
# Record is:  [1072, 1732, 1143, 1814, 'Biker']
# Record is:  [624, 837, 667, 903, 'Biker']
# Record is:  [774, 651, 828, 715, 'Person']
# Record is:  [813, 869, 862, 933, 'Biker']
# 2 1 1 0
# Ground Truth:  4
# imgs/test/little_video1_7950.jpg
# processing time:  0.07578682899475098
# Record is:  [457, 831, 502, 909, 'Biker']
# Record is:  [638, 867, 686, 929, 'Biker']
# 2 0 0 2
# Ground Truth:  4
# imgs/test/little_video1_7980.jpg
# processing time:  0.07427334785461426
# Record is:  [283, 822, 341, 896, 'Biker']
# 1 0 0 3
# Ground Truth:  4
# imgs/test/little_video1_8010.jpg
# processing time:  0.07503080368041992
# Record is:  [295, 852, 352, 917, 'Biker']
# Record is:  [116, 819, 166, 889, 'Biker']
# Record is:  [1198, 1738, 1263, 1815, 'Biker']
# Record is:  [1075, 1734, 1142, 1824, 'Biker']
# 3 1 0 1
# Ground Truth:  5
# imgs/test/little_video1_8040.jpg
# processing time:  0.074249267578125
# Record is:  [1091, 1733, 1156, 1826, 'Biker']
# Record is:  [121, 846, 175, 919, 'Biker']
# Record is:  [1250, 1738, 1294, 1807, 'Person']
# 2 1 0 0
# Ground Truth:  3
# imgs/test/little_video1_8070.jpg
# processing time:  0.07458329200744629
# Record is:  [1288, 1722, 1319, 1795, 'Person']
# 1 0 0 2
# Ground Truth:  3
# imgs/test/little_video1_8100.jpg
# processing time:  0.0743553638458252
# Record is:  [1194, 722, 1243, 780, 'Person']
# Record is:  [1157, 1756, 1200, 1822, 'Person']
# Record is:  [1285, 1702, 1320, 1763, 'Person']
# 2 0 1 0
# Ground Truth:  2
# imgs/test/little_video1_8130.jpg
# processing time:  0.07425093650817871
# Record is:  [1268, 1701, 1309, 1762, 'Person']
# Record is:  [1179, 1733, 1240, 1810, 'Biker']
# 0 1 1 0
# Ground Truth:  2
# imgs/test/little_video1_8160.jpg
# processing time:  0.07421755790710449
# Record is:  [1093, 725, 1135, 789, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_8190.jpg
# processing time:  0.07439541816711426
# Record is:  [1042, 721, 1086, 786, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_8220.jpg
# processing time:  0.07412004470825195
# Record is:  [1255, 1735, 1294, 1802, 'Person']
# Record is:  [986, 726, 1030, 797, 'Person']
# 1 0 1 0
# Ground Truth:  2
# imgs/test/little_video1_8250.jpg
# processing time:  0.0743565559387207
# Record is:  [937, 723, 980, 804, 'Person']
# Record is:  [1282, 1714, 1316, 1780, 'Person']
# 2 0 0 0
# Ground Truth:  2
# imgs/test/little_video1_8280.jpg
# processing time:  0.07387113571166992
# Record is:  [884, 722, 929, 797, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_8310.jpg
# processing time:  0.07429790496826172
# Record is:  [826, 720, 876, 798, 'Person']
# 1 0 0 2
# Ground Truth:  3
# imgs/test/little_video1_8340.jpg
# processing time:  0.07405281066894531
# Record is:  [778, 699, 830, 766, 'Person']
# 1 0 0 2
# Ground Truth:  3
# imgs/test/little_video1_8370.jpg
# processing time:  0.07476615905761719
# Record is:  [1235, 824, 1278, 903, 'Biker']
# Record is:  [717, 724, 771, 793, 'Person']
# Record is:  [139, 1161, 170, 1234, 'Person']
# 3 0 0 0
# Ground Truth:  3
# imgs/test/little_video1_8400.jpg
# processing time:  0.0742805004119873
# Record is:  [671, 728, 725, 798, 'Person']
# Record is:  [184, 1173, 225, 1247, 'Person']
# Record is:  [1046, 837, 1091, 916, 'Biker']
# 3 0 0 1
# Ground Truth:  4
# imgs/test/little_video1_8430.jpg
# processing time:  0.07384848594665527
# Record is:  [616, 733, 665, 800, 'Person']
# Record is:  [247, 1167, 288, 1242, 'Person']
# Record is:  [814, 908, 877, 967, 'Biker']
# 3 0 0 1
# Ground Truth:  4
# imgs/test/little_video1_8460.jpg
# processing time:  0.07471108436584473
# Record is:  [306, 1162, 348, 1234, 'Person']
# Record is:  [559, 736, 614, 810, 'Person']
# Record is:  [561, 916, 617, 980, 'Biker']
# Record is:  [659, 838, 702, 905, 'Biker']
# Record is:  [106, 1068, 149, 1133, 'Biker']
# 5 0 0 0
# Ground Truth:  5
# imgs/test/little_video1_8490.jpg
# processing time:  0.07407450675964355
# Record is:  [366, 1166, 410, 1237, 'Person']
# Record is:  [459, 849, 522, 920, 'Biker']
# Record is:  [503, 732, 557, 803, 'Person']
# 3 0 0 2
# Ground Truth:  5
# imgs/test/little_video1_8520.jpg
# processing time:  0.07423186302185059
# Record is:  [246, 857, 304, 927, 'Biker']
# Record is:  [479, 1047, 541, 1130, 'Biker']
# Record is:  [122, 913, 171, 973, 'Biker']
# Record is:  [453, 726, 504, 801, 'Person']
# 3 0 1 1
# Ground Truth:  5
# imgs/test/little_video1_8550.jpg
# processing time:  0.07494139671325684
# Record is:  [401, 725, 453, 798, 'Person']
# Record is:  [656, 1041, 701, 1109, 'Biker']
# 2 0 0 2
# Ground Truth:  4
# imgs/test/little_video1_8580.jpg
# processing time:  0.0744321346282959
# Record is:  [348, 720, 405, 800, 'Person']
# Record is:  [826, 1031, 882, 1100, 'Biker']
# Record is:  [517, 1182, 562, 1240, 'Person']
# Record is:  [1051, 824, 1099, 899, 'Biker']
# 4 0 0 0
# Ground Truth:  4
# imgs/test/little_video1_8610.jpg
# processing time:  0.07435464859008789
# Record is:  [575, 1168, 618, 1237, 'Person']
# Record is:  [287, 719, 348, 798, 'Person']
# Record is:  [1009, 1022, 1090, 1096, 'Biker']
# 3 0 0 1
# Ground Truth:  4
# imgs/test/little_video1_8640.jpg
# processing time:  0.07462215423583984
# Record is:  [637, 1158, 666, 1224, 'Person']
# Record is:  [239, 719, 293, 797, 'Person']
# Record is:  [1176, 1024, 1222, 1112, 'Biker']
# Record is:  [696, 842, 739, 923, 'Biker']
# 4 0 0 0
# Ground Truth:  4
# imgs/test/little_video1_8670.jpg
# processing time:  0.07487082481384277
# Record is:  [171, 719, 241, 790, 'Person']
# Record is:  [691, 1154, 719, 1221, 'Person']
# Record is:  [502, 846, 555, 928, 'Biker']
# 3 0 0 0
# Ground Truth:  3
# imgs/test/little_video1_8700.jpg
# processing time:  0.07384943962097168
# Record is:  [738, 1145, 775, 1217, 'Person']
# Record is:  [128, 717, 182, 794, 'Person']
# Record is:  [321, 844, 374, 924, 'Biker']
# 3 0 0 0
# Ground Truth:  3
# imgs/test/little_video1_8730.jpg
# processing time:  0.07462048530578613
# Record is:  [117, 841, 180, 919, 'Biker']
# Record is:  [786, 1170, 829, 1235, 'Person']
# 2 0 0 1
# Ground Truth:  3
# imgs/test/little_video1_8760.jpg
# processing time:  0.0749516487121582
# Record is:  [846, 1171, 877, 1236, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_8790.jpg
# processing time:  0.07415413856506348
# Record is:  [898, 1180, 937, 1245, 'Person']
# 1 0 0 0
# Ground Truth:  1
# imgs/test/little_video1_8820.jpg
# processing time:  0.07388043403625488
# Record is:  [953, 1184, 991, 1250, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_8850.jpg
# processing time:  0.07471609115600586
# Record is:  [1016, 1186, 1052, 1249, 'Person']
# Record is:  [1083, 1128, 1123, 1182, 'Person']
# 1 0 1 0
# Ground Truth:  2
# imgs/test/little_video1_8880.jpg
# processing time:  0.07363104820251465
# Record is:  [1249, 1204, 1288, 1259, 'Person']
# Record is:  [1063, 1188, 1093, 1247, 'Person']
# Record is:  [1048, 701, 1103, 783, 'Biker']
# 2 1 0 0
# Ground Truth:  3
# imgs/test/little_video1_8910.jpg
# processing time:  0.07502961158752441
# Record is:  [884, 1821, 926, 1893, 'Person']
# Record is:  [1115, 1192, 1144, 1243, 'Person']
# Record is:  [879, 694, 938, 786, 'Biker']
# Record is:  [1229, 841, 1283, 928, 'Biker']
# Record is:  [1066, 514, 1125, 568, 'Person']
# 1 2 2 0
# Ground Truth:  4
# imgs/test/little_video1_8940.jpg
# processing time:  0.07407402992248535
# Record is:  [1070, 864, 1127, 946, 'Biker']
# Record is:  [919, 1804, 963, 1870, 'Person']
# 0 2 0 3
# Ground Truth:  5
# imgs/test/little_video1_8970.jpg
# processing time:  0.07454895973205566
# Record is:  [878, 862, 934, 933, 'Biker']
# Record is:  [504, 708, 559, 790, 'Biker']
# Record is:  [1160, 1026, 1199, 1082, 'Person']
# 1 2 0 2
# Ground Truth:  5
# imgs/test/little_video1_9000.jpg
# processing time:  0.07445693016052246
# Record is:  [318, 705, 384, 777, 'Biker']
# Record is:  [702, 851, 760, 926, 'Biker']
# Record is:  [1239, 1288, 1275, 1358, 'Person']
# Record is:  [1083, 1720, 1136, 1810, 'Biker']
# Record is:  [1132, 978, 1174, 1041, 'Person']
# 3 1 1 2
# Ground Truth:  7
# imgs/test/little_video1_9030.jpg
# processing time:  0.07374906539916992
# Record is:  [529, 853, 595, 929, 'Biker']
# Record is:  [1182, 866, 1218, 931, 'Person']
# Record is:  [136, 705, 194, 774, 'Biker']
# 1 2 0 5
# Ground Truth:  8
# imgs/test/little_video1_9060.jpg
# processing time:  0.07384443283081055
# Record is:  [339, 837, 386, 911, 'Biker']
# 1 0 0 4
# Ground Truth:  5
# imgs/test/little_video1_9090.jpg
# processing time:  0.07444238662719727
# Record is:  [1227, 774, 1287, 851, 'Person']
# Record is:  [836, 859, 881, 934, 'Biker']
# Record is:  [148, 828, 220, 904, 'Biker']
# 2 0 1 1
# Ground Truth:  4
# imgs/test/little_video1_9120.jpg
# processing time:  0.07424473762512207
# Record is:  [1185, 762, 1217, 828, 'Person']
# Record is:  [668, 843, 732, 935, 'Biker']
# 2 0 0 3
# Ground Truth:  5
# imgs/test/little_video1_9150.jpg
# processing time:  0.07535815238952637
# Record is:  [489, 844, 534, 930, 'Biker']
# Record is:  [1123, 750, 1169, 815, 'Person']
# Record is:  [913, 753, 960, 825, 'Person']
# 2 0 1 1
# Ground Truth:  4
# imgs/test/little_video1_9180.jpg
# processing time:  0.07429194450378418
# Record is:  [1055, 738, 1100, 809, 'Person']
# Record is:  [338, 1004, 398, 1086, 'Biker']
# Record is:  [311, 843, 353, 923, 'Biker']
# Record is:  [860, 709, 925, 776, 'Person']
# 1 0 3 0
# Ground Truth:  4
# imgs/test/little_video1_9210.jpg
# processing time:  0.07516169548034668
# Record is:  [533, 1009, 591, 1093, 'Biker']
# Record is:  [124, 836, 168, 916, 'Biker']
# 0 0 2 2
# Ground Truth:  4
# imgs/test/little_video1_9240.jpg
# processing time:  0.07397985458374023
# Record is:  [713, 1008, 779, 1096, 'Biker']
# Record is:  [953, 722, 994, 787, 'Person']
# Record is:  [783, 611, 857, 680, 'Person']
# 2 0 1 0
# Ground Truth:  3
# imgs/test/little_video1_9270.jpg
# processing time:  0.07489156723022461
# Record is:  [888, 716, 939, 782, 'Person']
# Record is:  [884, 1015, 951, 1093, 'Biker']
# 1 0 1 1
# Ground Truth:  3
# imgs/test/little_video1_9300.jpg
# processing time:  0.07404661178588867
# Record is:  [1085, 997, 1157, 1088, 'Biker']
# 0 0 1 1
# Ground Truth:  2
# imgs/test/little_video1_9330.jpg
# processing time:  0.07451653480529785
# Record is:  [767, 645, 841, 705, 'Person']
# Record is:  [1252, 1010, 1304, 1070, 'Biker']
# Record is:  [751, 694, 826, 766, 'Person']
# 1 0 2 0
# Ground Truth:  1
# imgs/test/little_video1_9360.jpg
# processing time:  0.07528066635131836
# 0 0 0 1
# Ground Truth:  1
# imgs/test/little_video1_9390.jpg
# processing time:  0.07453727722167969
# Record is:  [780, 643, 832, 716, 'Person']
# Record is:  [642, 655, 704, 732, 'Person']
# 1 0 1 0
# Ground Truth:  1
# imgs/test/little_video1_9420.jpg
# processing time:  0.07519340515136719
# Record is:  [600, 609, 650, 692, 'Person']
# 1 0 0 0
# Ground Truth:  1
# imgs/test/little_video1_9450.jpg
# processing time:  0.07598161697387695
# 0 0 0 1
# Ground Truth:  1
# imgs/test/little_video1_9480.jpg
# processing time:  0.07579612731933594
# Record is:  [1149, 817, 1199, 897, 'Biker']
# 1 0 0 3
# Ground Truth:  4
# imgs/test/little_video1_9510.jpg
# processing time:  0.0746309757232666
# Record is:  [963, 825, 1021, 887, 'Biker']
# Record is:  [785, 651, 833, 711, 'Person']
# Record is:  [131, 1128, 165, 1193, 'Person']
# 2 0 1 0
# Ground Truth:  3
# imgs/test/little_video1_9540.jpg
# processing time:  0.0748755931854248
# Record is:  [784, 821, 829, 887, 'Biker']
# Record is:  [784, 654, 833, 721, 'Person']
# Record is:  [173, 1126, 220, 1192, 'Person']
# 1 0 2 0
# Ground Truth:  3
# imgs/test/little_video1_9570.jpg
# processing time:  0.07506346702575684
# Record is:  [786, 650, 832, 706, 'Person']
# 0 0 1 2
# Ground Truth:  3
# imgs/test/little_video1_9600.jpg
# processing time:  0.07487845420837402
# Record is:  [400, 819, 454, 895, 'Biker']
# Record is:  [245, 1125, 304, 1195, 'Biker']
# 1 0 1 1
# Ground Truth:  3
# imgs/test/little_video1_9630.jpg
# processing time:  0.07419443130493164
# Record is:  [306, 1126, 345, 1188, 'Person']
# Record is:  [199, 822, 258, 903, 'Biker']
# 2 0 0 1
# Ground Truth:  3
# imgs/test/little_video1_9660.jpg
# processing time:  0.0758507251739502
# Record is:  [349, 1124, 396, 1195, 'Person']
# 1 0 0 2
# Ground Truth:  3
# imgs/test/little_video1_9690.jpg
# processing time:  0.07458853721618652
# Record is:  [406, 1139, 444, 1196, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_9720.jpg
# processing time:  0.07576322555541992
# Record is:  [451, 1136, 484, 1196, 'Person']
# 1 0 0 1
# Ground Truth:  2
# imgs/test/little_video1_9750.jpg
# processing time:  0.07471442222595215
# Record is:  [477, 1132, 513, 1187, 'Person']
# Record is:  [519, 1126, 555, 1190, 'Person']
# 1 0 1 0
# Ground Truth:  2
# imgs/test/little_video1_9780.jpg
# processing time:  0.07517075538635254
# Record is:  [528, 1133, 558, 1187, 'Person']
# 0 0 1 1
# Ground Truth:  2
# imgs/test/little_video1_9810.jpg
# processing time:  0.07472586631774902
# Record is:  [581, 1135, 612, 1192, 'Person']
# 0 0 1 1
# Ground Truth:  2
# imgs/test/little_video1_9840.jpg
# processing time:  0.07458996772766113
# Record is:  [636, 1140, 668, 1188, 'Person']
# Record is:  [672, 1139, 705, 1194, 'Person']
# 0 0 2 0
# Ground Truth:  2
# imgs/test/little_video1_9870.jpg
# processing time:  0.07512259483337402
# Record is:  [682, 1142, 715, 1193, 'Person']
# Record is:  [1136, 905, 1202, 984, 'Biker']
# 2 0 0 1
# Ground Truth:  3
# imgs/test/little_video1_9900.jpg
# processing time:  0.0746612548828125
# Record is:  [719, 1122, 774, 1199, 'Biker']
# Record is:  [966, 904, 1027, 979, 'Biker']
# 1 1 0 1
# Ground Truth:  3
# imgs/test/little_video1_9930.jpg
# processing time:  0.07451319694519043
# Record is:  [770, 1140, 803, 1198, 'Person']
# Record is:  [787, 906, 838, 987, 'Biker']
# Record is:  [64, 1046, 113, 1120, 'Biker']
# 2 0 1 1
# Ground Truth:  4
# imgs/test/little_video1_9960.jpg
# processing time:  0.07404112815856934
# Record is:  [616, 909, 678, 981, 'Biker']
# Record is:  [388, 1023, 451, 1099, 'Biker']
# Record is:  [838, 1130, 868, 1194, 'Person']
# 3 0 0 1
# Ground Truth:  4
# imgs/test/little_video1_9990.jpg
# processing time:  0.07443737983703613
# Record is:  [443, 904, 511, 979, 'Biker']
# Record is:  [703, 1017, 762, 1097, 'Biker']
# Record is:  [1064, 521, 1122, 571, 'Person']
# Record is:  [862, 1132, 897, 1194, 'Person']
# Record is:  [887, 1136, 921, 1201, 'Person']
# 4 0 1 1
# Ground Truth:  5
# imgs/test/quad_video2_300.jpg
# processing time:  0.17006754875183105
# Record is:  [368, 0, 424, 38, 'Person']
# 1 0 0 12
# Ground Truth:  13
# imgs/test/quad_video2_330.jpg
# processing time:  0.07553791999816895
# Record is:  [476, 7, 532, 42, 'Person']
# 1 0 0 12
# Ground Truth:  13
# imgs/test/quad_video2_360.jpg
# processing time:  0.07599139213562012
# Record is:  [1520, 396, 1556, 431, 'Person']
# Record is:  [1761, 785, 1804, 823, 'Person']
# Record is:  [1495, 429, 1535, 467, 'Person']
# 1 0 2 10
# Ground Truth:  13
# imgs/test/quad_video2_390.jpg
# processing time:  0.07558321952819824
# Record is:  [1861, 6, 1904, 34, 'Biker']
# Record is:  [1768, 809, 1808, 843, 'Person']
# Record is:  [1498, 403, 1543, 439, 'Biker']
# 1 1 1 11
# Ground Truth:  14
# imgs/test/quad_video2_420.jpg
# processing time:  0.07639765739440918
# Record is:  [832, 0, 891, 68, 'Person']
# Record is:  [1505, 408, 1542, 443, 'Person']
# 1 0 1 11
# Ground Truth:  13
# imgs/test/quad_video2_450.jpg
# processing time:  0.07526397705078125
# Record is:  [1772, 800, 1805, 831, 'Person']
# Record is:  [1523, 971, 1563, 1021, 'Person']
# Record is:  [1483, 443, 1530, 485, 'Person']
# 1 0 2 10
# Ground Truth:  13
# imgs/test/quad_video2_480.jpg
# processing time:  0.07646036148071289
# Record is:  [1514, 397, 1547, 435, 'Person']
# Record is:  [1628, 653, 1659, 685, 'Person']
# Record is:  [1495, 437, 1536, 480, 'Person']
# 1 0 2 9
# Ground Truth:  12

# %% [markdown]
# #Metrics

# %%
print(total_true_positive, total_class_mismatch, total_false_positive, total_false_negative, total_gt)
# Out:
# 5515 60 283 1077 6868

# %%
precision = total_true_positive/(total_true_positive+total_false_positive)

recall = total_true_positive/(total_true_positive+ total_false_negative)

f1_score = 2*(precision * recall)/(precision + recall)

accuracy = (total_true_positive ) / (total_true_positive+total_false_positive+total_false_negative)

print(precision, recall, f1_score,accuracy)
# Out:
# 0.9511900655398413 0.836620145631068 0.8902340597255852 0.8021818181818182

# %% [markdown]
# Confusion matrix section

# %%
predictions = []
for sublist in tp_cl2:
    for item in sublist:
        predictions.append(item)

print(len(predictions))

person_cnt_tp = 0
biker_cnt_tp = 0
car_cnt_tp = 0
bus_cnt_tp = 0

for i in predictions:
  if i == "Person":
    person_cnt_tp += 1
  if i == "Biker":
    biker_cnt_tp += 1
  if i == "Car":
    car_cnt_tp += 1
  if i == "Bus":
    bus_cnt_tp += 1

print(f"True positive: Person: {person_cnt_tp}, Biker: {biker_cnt_tp}, Car: {car_cnt_tp}, Bus: {bus_cnt_tp}")
# Out:
# 5515
# True positive: Person: 4788, Biker: 694, Car: 11, Bus: 22

# %%
predictions2 = []
for sublist in cm_cl2:
    for item in sublist:
        predictions2.append(item)

print(len(predictions2))

person_cnt_cm = 0
biker_cnt_cm = 0
car_cnt_cm = 0
bus_cnt_cm = 0

for i in predictions2:
  if i == "Person":
    person_cnt_cm += 1
  if i == "Biker":
    biker_cnt_cm += 1
  if i == "Car":
    car_cnt_cm += 1
  if i == "Bus":
    bus_cnt_cm += 1

print(f"Class Missmatch: Person: {person_cnt_cm}, Biker: {biker_cnt_cm}, Car: {car_cnt_cm}, Bus: {bus_cnt_cm}")
# Out:
# 60
# Class Missmatch: Person: 20, Biker: 40, Car: 0, Bus: 0

# %%
predictions3 = []
for sublist in fp_cl2:
    for item in sublist:
        predictions3.append(item)

print(len(predictions3))

person_cnt_fp = 0
biker_cnt_fp = 0
car_cnt_fp = 0
bus_cnt_fp = 0

for i in predictions3:
  if i == "Person":
    person_cnt_fp += 1
  if i == "Biker":
    biker_cnt_fp += 1
  if i == "Car":
    car_cnt_fp += 1
  if i == "Bus":
    bus_cnt_fp += 1

print(f"False positive: Person: {person_cnt_fp}, Biker: {biker_cnt_fp}, Car: {car_cnt_fp}, Bus: {bus_cnt_fp}")
# Out:
# 283
# False positive: Person: 177, Biker: 104, Car: 2, Bus: 0

# %%
predictions4 = []
for sublist in fn_cl2:
    for item in sublist:
        predictions4.append(item)

print(len(predictions4))

person_cnt_fn = 0
biker_cnt_fn = 0
car_cnt_fn = 0
bus_cnt_fn = 0

for i in predictions4:
  if i == "Person":
    person_cnt_fn += 1
  if i == "Biker":
    biker_cnt_fn += 1
  if i == "Car":
    car_cnt_fn += 1
  if i == "Bus":
    bus_cnt_fn += 1

print(f"False negative: Person: {person_cnt_fn}, Biker: {biker_cnt_fn}, Car: {car_cnt_fn}, Bus: {bus_cnt_fn}")
# Out:
# 1077
# False negative: Person: 644, Biker: 404, Car: 24, Bus: 5
